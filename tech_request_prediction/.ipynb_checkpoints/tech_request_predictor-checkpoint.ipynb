# %% [markdown]
# # О проекте

# %% [markdown]
# ---
#
# ### 📌 **Описание проекта: Предсказание предоставления техники на строительных объектах**
#
# В рамках деятельности строительной компании для организации строительных процессов используется внутреннее веб-приложение, через которое с марта 2025 года осуществляется подача заявок на предоставление строительной техники. Все заявки автоматически сохраняются в Google Таблицу, где диспетчер впоследствии фиксирует факт и объём предоставленной техники по каждой заявке.
#
# На основе накопленных данных формируются аналитические графики, отражающие активность и эффективность предоставления техники по дням, объектам и категориям.
#
# **Цель проекта** — разработать модель машинного обучения, способную предсказывать вероятность предоставления техники по новой заявке. Это позволит:
#
# * повысить прозрачность процессов;
# * более эффективно планировать ресурсы;
# * оперативно информировать инициаторов заявок о вероятности их удовлетворения.
#
# **Ключевые этапы проекта:**
#
# * анализ и предобработка данных из Google Таблицы;
# * построение признаков на основе параметров заявки (дата, объект, категория техники, количество и т.д.);
# * обучение классификационной модели на исторических данных;
# * интеграция модели в процесс подачи заявки с возможностью мгновенного отображения вероятности предоставления техники.
#
# Проект направлен на оптимизацию логистики и управление ожиданиями всех участников строительного процесса.
#
# ---
