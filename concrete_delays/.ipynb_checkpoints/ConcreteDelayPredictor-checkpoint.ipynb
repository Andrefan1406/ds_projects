# %% [markdown]
# # О проекте

# %% [markdown]
# В рамках строительной компании ведётся цифровой учёт заявок на поставку бетона через Google Forms. Все заявки автоматически сохраняются в Google Таблицу, где также фиксируется информация об исполнении — фактическая дата поставки, объём, отклонения и прочие параметры. Сбор данных ведётся с июня 2024 года, и на текущий момент накоплен достаточный объём информации для проведения анализа и построения предиктивной модели.
#
# В процессе поставок периодически возникают задержки: бетон может быть доставлен на строительную площадку с опозданием на один или несколько дней. Цель проекта — разработать модель машинного обучения, которая будет предсказывать вероятность задержки в поставке бетона.
#
# Возможны два подхода:
#
# * **Классификация** — модель предсказывает факт задержки (да/нет);
# * **Регрессия** — модель предсказывает количество дней задержки (если она будет).
#
# Модель позволит заранее выявлять риск отклонений от графика и своевременно принимать управленческие решения.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    f1_score, 
    confusion_matrix, 
    roc_auc_score, 
    classification_report, 
    recall_score, 
    ConfusionMatrixDisplay
)

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQYF7LcaaZJQNEdQ502p8vkRTnvXn2xUHENQdTwRL2zOgM26uAgnyfgxvbzjZVE7eY0W99Somk5FhTd/pub?gid=655205162&single=true&output=csv')
df.head()
# Out:
#        Отметка времени Выберите дату доставки  \
# 0  06.06.2024 12:09:28             07.06.2024
# 1  06.06.2024 15:26:16             07.06.2024
# 2  06.06.2024 15:28:09             07.06.2024
# 3  06.06.2024 19:06:54             07.06.2024
# 4   07.06.2024 8:22:02             07.06.2024
#
#   Укажите время доставки на объект или нажмите далее  \
# 0                                               8:00
# 1                                     9:00 Д\Т школа
# 2                                              08:00
# 3                                               9-00
# 4                                               9:00
#
#   Выберите тип строительства Выберите объект Выберите объект.1  \
# 0                     Здание             NaN               NaN
# 1            Благоустройство             NaN               NaN
# 2                     Здание             NaN               NaN
# 3                     Здание             NaN               NaN
# 4            Благоустройство             NaN               NaN
#
#   Укажите конструктив Выберите объект.2 Выберите конструкцию  \
# 0                 NaN               NaN                  NaN
# 1                 NaN               NaN                  NaN
# 2                 NaN               NaN                  NaN
# 3                 NaN               NaN                  NaN
# 4                 NaN               NaN                  NaN
#
#   Выберите объект.3  ... Укажите необходимый объём; м3  \
# 0             СПОРТ  ...                            90
# 1               NaN  ...                             3
# 2             СПОРТ  ...                            90
# 3   Школа Нурлы Жол  ...                             2
# 4               NaN  ...                           2,5
#
#   ФИО (ответственного за приёмку бетона)  \
# 0                          Адаменко О.Ю.
# 1                        Нуршабаев Манат
# 2                          Адаменко О.Ю.
# 3                             Алинов К.М
# 4                        Нуршабаев Манат
#
#   Телефон (ответственного за приёмку бетона) Выберите позицию.2 Unnamed: 42  \
# 0                                87771456752                NaN         NaN
# 1                                 7763030297                NaN         NaN
# 2                                87771456752                NaN         NaN
# 3                                87051854684                NaN         NaN
# 4                                 7763030297                NaN         NaN
#
#   Выберите конструкцию  Выберите конструкцию.3 Unnamed: 45 Unnamed: 46  \
# 0                   NaN                    NaN         NaN         NaN
# 1                   NaN                    NaN         NaN         NaN
# 2                   NaN                    NaN         NaN         NaN
# 3                   NaN                    NaN         NaN         NaN
# 4                   NaN                    NaN         NaN         NaN
#
#   Unnamed: 47
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4537 entries, 0 to 4536
# Data columns (total 48 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Отметка времени                                     4523 non-null   object
#  1   Выберите дату доставки                              4523 non-null   object
#  2   Укажите время доставки на объект или нажмите далее  3590 non-null   object
#  3   Выберите тип строительства                          4517 non-null   object
#  4   Выберите объект                                     355 non-null    object
#  5   Выберите объект.1                                   1168 non-null   object
#  6   Укажите конструктив                                 1509 non-null   object
#  7   Выберите объект.2                                   153 non-null    object
#  8   Выберите конструкцию                                153 non-null    object
#  9   Выберите объект.3                                   2286 non-null   object
#  10  Выберите объект.4                                   496 non-null    object
#  11  Выберите конструктив                                496 non-null    object
#  12  Выберите блок                                       306 non-null    object
#  13  Выберите блок.1                                     327 non-null    object
#  14  Выберите позицию                                    991 non-null    object
#  15  Выберите позицию.1                                  467 non-null    object
#  16  Выберите блок.2                                     31 non-null     object
#  17  Выберите блок.3                                     299 non-null    object
#  18  Выберите блок.4                                     172 non-null    object
#  19  Выберите блок.5                                     421 non-null    object
#  20  Выберите этаж                                       349 non-null    object
#  21  Выберите этаж.1                                     368 non-null    object
#  22  Выберите этаж.2                                     647 non-null    object
#  23  Выберите этаж.3                                     76 non-null     object
#  24  Выберите конструктив.1                              60 non-null     object
#  25  Выберите конструктив.2                              3 non-null      object
#  26  Выберите конструктив.3                              13 non-null     object
#  27  Выберите этаж.4                                     325 non-null    object
#  28  Выберите этаж.5                                     204 non-null    object
#  29  Выберите этаж.6                                     35 non-null     object
#  30  Выберите конструктив.4                              340 non-null    object
#  31  Выберите конструктив.5                              1434 non-null   object
#  32  Выберите конструкцию.1                              107 non-null    object
#  33  Выберите конструкцию.2                              50 non-null     object
#  34  Выберите материал                                   4523 non-null   object
#  35  Выберите марку раствора                             1600 non-null   object
#  36  Выберите класс бетона                               2917 non-null   object
#  37  Выберите подвижность бетона                         2917 non-null   object
#  38  Укажите необходимый объём; м3                       4522 non-null   object
#  39  ФИО (ответственного за приёмку бетона)              4516 non-null   object
#  40  Телефон (ответственного за приёмку бетона)          4517 non-null   object
#  41  Выберите позицию.2                                  35 non-null     object
#  42  Unnamed: 42                                         19 non-null     object
#  43  Выберите конструкцию                                16 non-null     object
#  44  Выберите конструкцию.3                              19 non-null     object
#  45  Unnamed: 45                                         0 non-null      float64
#  46  Unnamed: 46                                         0 non-null      float64
#  47  Unnamed: 47                                         1 non-null      float64
# dtypes: float64(3), object(45)
# memory usage: 1.7+ MB

# %%
df['object'] = (df['Выберите объект'].fillna('') + 
                df['Выберите объект.1'].fillna('') + 
                df['Выберите объект.2'].fillna('') +
                df['Выберите объект.3'].fillna('') +
                df['Выберите объект.4'].fillna(''))

# %%
df['position'] = (df['Выберите позицию'].fillna('') + 
                  df['Выберите позицию.1'].fillna('') +
                  df['Выберите позицию.2'].fillna(''))

# %%
df['block'] = (df['Выберите блок'].fillna('') + 
               df['Выберите блок.1'].fillna('') +
               df['Выберите блок.2'].fillna('') +
               df['Выберите блок.3'].fillna('') +
               df['Выберите блок.4'].fillna('') +
               df['Выберите блок.5'].fillna(''))

# %%
df['constructive'] = (df['Укажите конструктив'].fillna('') + 
               df['Выберите конструкцию'].fillna('') + 
               df['Выберите конструкцию '].fillna('') + 
               df['Выберите конструктив'].fillna('') +  
               df['Выберите конструктив.1'].fillna('') + 
               df['Выберите конструктив.2'].fillna('') + 
               df['Выберите конструктив.3'].fillna('') + 
               df['Выберите конструктив.4'].fillna('') + 
               df['Выберите конструктив.5'].fillna('') + 
               df['Выберите конструкцию.1'].fillna('') + 
               df['Выберите конструкцию.2'].fillna('') + 
               df['Выберите конструкцию.3'].fillna(''))

# %%
df['floor'] = (df['Выберите этаж'].fillna('') + 
               df['Выберите этаж.1'].fillna('') +
               df['Выберите этаж.2'].fillna('') +
               df['Выберите этаж.3'].fillna('') +
               df['Выберите этаж.4'].fillna('') +
               df['Выберите этаж.5'].fillna('') +
               df['Выберите этаж.6'].fillna(''))

# %%
df['material_class'] = (df['Выберите марку раствора'].fillna('') + 
                        df['Выберите класс бетона'].fillna(''))

# %%
df.columns
# Out:
# Index(['Отметка времени', 'Выберите дату доставки',
#        'Укажите время доставки на объект или нажмите далее',
#        'Выберите тип строительства', 'Выберите объект', 'Выберите объект.1',
#        'Укажите конструктив', 'Выберите объект.2', 'Выберите конструкцию',
#        'Выберите объект.3', 'Выберите объект.4', 'Выберите конструктив',
#        'Выберите блок', 'Выберите блок.1', 'Выберите позицию',
#        'Выберите позицию.1', 'Выберите блок.2', 'Выберите блок.3',
#        'Выберите блок.4', 'Выберите блок.5', 'Выберите этаж',
#        'Выберите этаж.1', 'Выберите этаж.2', 'Выберите этаж.3',
#        'Выберите конструктив.1', 'Выберите конструктив.2',
#        'Выберите конструктив.3', 'Выберите этаж.4', 'Выберите этаж.5',
#        'Выберите этаж.6', 'Выберите конструктив.4', 'Выберите конструктив.5',
#        'Выберите конструкцию.1', 'Выберите конструкцию.2', 'Выберите материал',
#        'Выберите марку раствора', 'Выберите класс бетона',
#        'Выберите подвижность бетона', 'Укажите необходимый объём; м3',
#        'ФИО (ответственного за приёмку бетона)',
#        'Телефон (ответственного за приёмку бетона)', 'Выберите позицию.2',
#        'Unnamed: 42', 'Выберите конструкцию ', 'Выберите конструкцию.3',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'object', 'position',
#        'block', 'constructive', 'floor', 'material_class'],
#       dtype='object')

# %%
df_filtered_columns = df.drop(columns=['Unnamed: 42', 
                                       'Unnamed: 45', 
                                       'Unnamed: 46', 
                                       'Unnamed: 47',
                                       'Выберите объект', 
                                       'Выберите объект.1',
                                       'Выберите объект.2',
                                       'Выберите объект.3',
                                       'Выберите объект.4',
                                       'Выберите блок',
                                       'Выберите блок.1',
                                       'Выберите блок.2',
                                       'Выберите блок.3',
                                       'Выберите блок.4',
                                       'Выберите блок.5',
                                       'Выберите позицию',
                                       'Выберите позицию.1',
                                       'Выберите позицию.2',
                                       'Укажите конструктив',
                                       'Выберите конструкцию',
                                       'Выберите конструкцию ',
                                       'Выберите конструктив',  
                                       'Выберите конструктив.1', 
                                       'Выберите конструктив.2', 
                                       'Выберите конструктив.3', 
                                       'Выберите конструктив.4', 
                                       'Выберите конструктив.5', 
                                       'Выберите конструкцию.1',
                                       'Выберите конструкцию.2',
                                       'Выберите конструкцию.3',
                                       'Выберите этаж',
                                       'Выберите этаж.1',
                                       'Выберите этаж.2',
                                       'Выберите этаж.3',
                                       'Выберите этаж.4',
                                       'Выберите этаж.5',
                                       'Выберите этаж.6',
                                       'Выберите марку раствора',
                                       'Выберите класс бетона'], axis=1)
df_filtered_columns.head()
# Out:
#        Отметка времени Выберите дату доставки  \
# 0  06.06.2024 12:09:28             07.06.2024
# 1  06.06.2024 15:26:16             07.06.2024
# 2  06.06.2024 15:28:09             07.06.2024
# 3  06.06.2024 19:06:54             07.06.2024
# 4   07.06.2024 8:22:02             07.06.2024
#
#   Укажите время доставки на объект или нажмите далее  \
# 0                                               8:00
# 1                                     9:00 Д\Т школа
# 2                                              08:00
# 3                                               9-00
# 4                                               9:00
#
#   Выберите тип строительства Выберите материал Выберите подвижность бетона  \
# 0                     Здание             Бетон                          П4
# 1            Благоустройство             Бетон                          П3
# 2                     Здание             Бетон                          П4
# 3                     Здание             Бетон                          П4
# 4            Благоустройство             Бетон                          П3
#
#   Укажите необходимый объём; м3 ФИО (ответственного за приёмку бетона)  \
# 0                            90                          Адаменко О.Ю.
# 1                             3                        Нуршабаев Манат
# 2                            90                          Адаменко О.Ю.
# 3                             2                             Алинов К.М
# 4                           2,5                        Нуршабаев Манат
#
#   Телефон (ответственного за приёмку бетона)  \
# 0                                87771456752
# 1                                 7763030297
# 2                                87771456752
# 3                                87051854684
# 4                                 7763030297
#
#                               object position block       constructive  \
# 0                              СПОРТ   поз.74                 Вертикал
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
#
#     floor material_class
# 0  8 этаж           В 25
# 1                   В 15
# 2  8 этаж        В 25 СС
# 3                   В 25
# 4                   В 15

# %%
df_filtered_columns = df_filtered_columns.rename(columns={
    'Отметка времени' : 'application_submission_datetime',
    'Выберите дату доставки' : 'planned_delivery_date',
    'Укажите время доставки на объект или нажмите далее' : 'planned_delivery_time',
    'Выберите тип строительства' : 'type',
    'Выберите материал' : 'material',
    'Выберите подвижность бетона' : 'mobility',
    'Укажите необходимый объём; м3' : 'volume',
    'ФИО (ответственного за приёмку бетона)' : 'full_name',
    'Телефон (ответственного за приёмку бетона)' : 'phone'
})

# %%
df_filtered_columns.head()
# Out:
#   application_submission_datetime planned_delivery_date planned_delivery_time  \
# 0             06.06.2024 12:09:28            07.06.2024                  8:00
# 1             06.06.2024 15:26:16            07.06.2024        9:00 Д\Т школа
# 2             06.06.2024 15:28:09            07.06.2024                 08:00
# 3             06.06.2024 19:06:54            07.06.2024                  9-00
# 4              07.06.2024 8:22:02            07.06.2024                  9:00
#
#               type material mobility volume        full_name        phone  \
# 0           Здание    Бетон       П4     90    Адаменко О.Ю.  87771456752
# 1  Благоустройство    Бетон       П3      3  Нуршабаев Манат   7763030297
# 2           Здание    Бетон       П4     90    Адаменко О.Ю.  87771456752
# 3           Здание    Бетон       П4      2       Алинов К.М  87051854684
# 4  Благоустройство    Бетон       П3    2,5  Нуршабаев Манат   7763030297
#
#                               object position block       constructive  \
# 0                              СПОРТ   поз.74                 Вертикал
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
#
#     floor material_class
# 0  8 этаж           В 25
# 1                   В 15
# 2  8 этаж        В 25 СС
# 3                   В 25
# 4                   В 15

# %%
df_filtered_columns['planned_delivery_time'] = (df_filtered_columns['planned_delivery_time']
                                                .str.split(' ')
                                                .str[0])
df_filtered_columns['planned_delivery_time'] = df_filtered_columns['planned_delivery_time'].str.split('(').str[0]
df_filtered_columns['planned_delivery_time'] = df_filtered_columns['planned_delivery_time'].str.replace(r'[-=*_"]', ':', regex=True)
df_filtered_columns['planned_delivery_time'] = (df_filtered_columns['planned_delivery_time']
                                                .replace(['', '8.06.2024', '9.06.2024','Нурлы','С',
                                                          'По', '29.06.2024', '08,07,2024', 'В','Школа',
                                                          '06,08,2024', 'Комфортная', '14.08.2024',
                                                          '15.08.2024', '4.09.2024', '6.09.2024',
                                                          'Детский', 'Азимхан', 'Глубоковский',
                                                          '28,10,2024', '29.10.2024', '1.11.2024',
                                                          'Манат','НЖ3', 'Кирпичный',
                                                          '45','1,5', 'Новоявленке'], np.nan))
df_filtered_columns['planned_delivery_time'] = df_filtered_columns['planned_delivery_time'].str.replace(r'[.]', ':', regex=True)
df_filtered_columns['planned_delivery_time'] = (df_filtered_columns['planned_delivery_time']
                                                .replace({'800' : '8:00', 
                                                          '1300' : '13:00', 
                                                          'в8:00' : '8:00', 
                                                          'В8:00' : '8:00',
                                                          'в' : np.nan, 
                                                          ',9:00' : '9:00', 
                                                          '0,75' : np.nan, 
                                                          '830' : '8:30',
                                                          '111' : '11:00', 
                                                          '1400' : '14:00',
                                                          '1600' : '16:00', 
                                                          '1,3' : '13:30', 
                                                          '900' : '9:00', 
                                                          '1000' : '10:00', 
                                                          '1500' : '15:00',
                                                          '0900' : '9:00'}))

df_filtered_columns['planned_delivery_time'] = df_filtered_columns['planned_delivery_time'].str.split(r'[:,;]').str[0]
df_filtered_columns['planned_delivery_time'] = (df_filtered_columns['planned_delivery_time']
                                                .replace({'08' : '8', 
                                                          '09' : '9', 
                                                          '00' : np.nan, 
                                                          '07' : '7',
                                                          '4' : '16',
                                                          '3' : '15',
                                                          '5' : '17'}))

mode_hours = df_filtered_columns['planned_delivery_time'].mode()[0]
df_filtered_columns['planned_delivery_time'] = df_filtered_columns['planned_delivery_time'].fillna(mode_hours)

# %%
df_report = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQYF7LcaaZJQNEdQ502p8vkRTnvXn2xUHENQdTwRL2zOgM26uAgnyfgxvbzjZVE7eY0W99Somk5FhTd/pub?gid=61989395&single=true&output=csv')
df_report.head()
# Out:
#   Дата и время подачи заявки Дата доставки бетона Время доставки бетона  \
# 0        06.06.2024 12:09:28           07.06.2024                  8:00
# 1        06.06.2024 15:26:16           07.06.2024        9:00 Д\Т школа
# 2        06.06.2024 15:28:09           07.06.2024                 08:00
# 3        06.06.2024 19:06:54           07.06.2024                  9-00
# 4         07.06.2024 8:22:02           07.06.2024                  9:00
#
#                               Объект           Блок, позиция Материал  \
# 0                              СПОРТ  поз.74 8 этаж Вертикал    Бетон
# 1  Благоустройство Школа (Нурлы Жол)                     NaN    Бетон
# 2                              СПОРТ  поз.74 8 этаж Вертикал    Бетон
# 3                    Школа Нурлы Жол        Световые приямки    Бетон
# 4              Благоустройство СПОРТ                     NaN    Бетон
#
#   Марка, класс Подвижность Объём, м3 ФИО (ответственного за приёмку бетона)  \
# 0         В 25          П4        90                          Адаменко О.Ю.
# 1         В 15          П3         3                        Нуршабаев Манат
# 2      В 25 СС          П4        90                          Адаменко О.Ю.
# 3         В 25          П4         2                             Алинов К.М
# 4         В 15          П3       2,5                        Нуршабаев Манат
#
#   Телефон (ответственного за приёмку бетона) Дата отгрузки Фактический объём  \
# 0                                87771456752           NaN               NaN
# 1                                 7763030297    07.06.2024                 3
# 2                                87771456752    09.06.2024                96
# 3                                87051854684    11.06.2024               1,5
# 4                                 7763030297    07.06.2024               2,5
#
#   Отметка о исполнении Согласование геодезистов Категория  \
# 0             Отменено                      NaN       СМР
# 1            Исполнено                      NaN       СМР
# 2            Исполнено              Согласовано       СМР
# 3            Исполнено                      NaN       СМР
# 4            Исполнено                      NaN       СМР
#
#   Согласование энергетиков
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_report = df_report[['Дата и время подачи заявки', 'Дата отгрузки',
                       'Отметка о исполнении', 'Фактический объём']]
df_report.head()
# Out:
#   Дата и время подачи заявки Дата отгрузки Отметка о исполнении  \
# 0        06.06.2024 12:09:28           NaN             Отменено
# 1        06.06.2024 15:26:16    07.06.2024            Исполнено
# 2        06.06.2024 15:28:09    09.06.2024            Исполнено
# 3        06.06.2024 19:06:54    11.06.2024            Исполнено
# 4         07.06.2024 8:22:02    07.06.2024            Исполнено
#
#   Фактический объём
# 0               NaN
# 1                 3
# 2                96
# 3               1,5
# 4               2,5

# %%
df_merged = pd.merge(df_filtered_columns, df_report, 
                     left_on='application_submission_datetime',
                     right_on='Дата и время подачи заявки',
                     how='inner')
df_merged.head()
# Out:
#   application_submission_datetime planned_delivery_date planned_delivery_time  \
# 0             06.06.2024 12:09:28            07.06.2024                     8
# 1             06.06.2024 15:26:16            07.06.2024                     9
# 2             06.06.2024 15:28:09            07.06.2024                     8
# 3             06.06.2024 19:06:54            07.06.2024                     9
# 4              07.06.2024 8:22:02            07.06.2024                     9
#
#               type material mobility volume        full_name        phone  \
# 0           Здание    Бетон       П4     90    Адаменко О.Ю.  87771456752
# 1  Благоустройство    Бетон       П3      3  Нуршабаев Манат   7763030297
# 2           Здание    Бетон       П4     90    Адаменко О.Ю.  87771456752
# 3           Здание    Бетон       П4      2       Алинов К.М  87051854684
# 4  Благоустройство    Бетон       П3    2,5  Нуршабаев Манат   7763030297
#
#                               object position block       constructive  \
# 0                              СПОРТ   поз.74                 Вертикал
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
#
#     floor material_class Дата и время подачи заявки Дата отгрузки  \
# 0  8 этаж           В 25        06.06.2024 12:09:28           NaN
# 1                   В 15        06.06.2024 15:26:16    07.06.2024
# 2  8 этаж        В 25 СС        06.06.2024 15:28:09    09.06.2024
# 3                   В 25        06.06.2024 19:06:54    11.06.2024
# 4                   В 15         07.06.2024 8:22:02    07.06.2024
#
#   Отметка о исполнении Фактический объём
# 0             Отменено               NaN
# 1            Исполнено                 3
# 2            Исполнено                96
# 3            Исполнено               1,5
# 4            Исполнено               2,5

# %%
df_merged[['application_submission_date', 'application_submission_time']] = (df_merged['application_submission_datetime']
                                                                             .str.split(' ', expand=True))
df_merged['application_submission_time'] = df_merged['application_submission_time'].str.split(':').str[0]
df_merged = df_merged.drop(columns=['application_submission_datetime', 'Дата и время подачи заявки'], axis=1)
df_merged.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 0            07.06.2024                     8           Здание    Бетон
# 1            07.06.2024                     9  Благоустройство    Бетон
# 2            07.06.2024                     8           Здание    Бетон
# 3            07.06.2024                     9           Здание    Бетон
# 4            07.06.2024                     9  Благоустройство    Бетон
#
#   mobility volume        full_name        phone  \
# 0       П4     90    Адаменко О.Ю.  87771456752
# 1       П3      3  Нуршабаев Манат   7763030297
# 2       П4     90    Адаменко О.Ю.  87771456752
# 3       П4      2       Алинов К.М  87051854684
# 4       П3    2,5  Нуршабаев Манат   7763030297
#
#                               object position block       constructive  \
# 0                              СПОРТ   поз.74                 Вертикал
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
#
#     floor material_class Дата отгрузки Отметка о исполнении Фактический объём  \
# 0  8 этаж           В 25           NaN             Отменено               NaN
# 1                   В 15    07.06.2024            Исполнено                 3
# 2  8 этаж        В 25 СС    09.06.2024            Исполнено                96
# 3                   В 25    11.06.2024            Исполнено               1,5
# 4                   В 15    07.06.2024            Исполнено               2,5
#
#   application_submission_date application_submission_time
# 0                  06.06.2024                          12
# 1                  06.06.2024                          15
# 2                  06.06.2024                          15
# 3                  06.06.2024                          19
# 4                  07.06.2024                           8

# %%
df_completed = df_merged[df_merged['Отметка о исполнении'] == 'Исполнено'].drop(columns='Отметка о исполнении', axis=1)
df_completed.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            07.06.2024                     9  Благоустройство    Бетон
# 2            07.06.2024                     8           Здание    Бетон
# 3            07.06.2024                     9           Здание    Бетон
# 4            07.06.2024                     9  Благоустройство    Бетон
# 5            07.06.2024                     8           Здание    Бетон
#
#   mobility volume        full_name        phone  \
# 1       П3      3  Нуршабаев Манат   7763030297
# 2       П4     90    Адаменко О.Ю.  87771456752
# 3       П4      2       Алинов К.М  87051854684
# 4       П3    2,5  Нуршабаев Манат   7763030297
# 5       П3    160         Масхут.Б  87051506578
#
#                               object position block       constructive  \
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
# 5                        Нурлы Жол 3   поз.64                 Вертикал
#
#     floor material_class Дата отгрузки Фактический объём  \
# 1                   В 15    07.06.2024                 3
# 2  8 этаж        В 25 СС    09.06.2024                96
# 3                   В 25    11.06.2024               1,5
# 4                   В 15    07.06.2024               2,5
# 5  1 этаж           В 25    07.06.2024               191
#
#   application_submission_date application_submission_time
# 1                  06.06.2024                          15
# 2                  06.06.2024                          15
# 3                  06.06.2024                          19
# 4                  07.06.2024                           8
# 5                  07.06.2024                           9

# %%
df_completed = df_completed.rename(columns = 
                                   {
                                       'Дата отгрузки' : 'actual_delivery_date',
                                       'Фактический объём' : 'fact_volume'
                                   })
df_completed.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            07.06.2024                     9  Благоустройство    Бетон
# 2            07.06.2024                     8           Здание    Бетон
# 3            07.06.2024                     9           Здание    Бетон
# 4            07.06.2024                     9  Благоустройство    Бетон
# 5            07.06.2024                     8           Здание    Бетон
#
#   mobility volume        full_name        phone  \
# 1       П3      3  Нуршабаев Манат   7763030297
# 2       П4     90    Адаменко О.Ю.  87771456752
# 3       П4      2       Алинов К.М  87051854684
# 4       П3    2,5  Нуршабаев Манат   7763030297
# 5       П3    160         Масхут.Б  87051506578
#
#                               object position block       constructive  \
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
# 5                        Нурлы Жол 3   поз.64                 Вертикал
#
#     floor material_class actual_delivery_date fact_volume  \
# 1                   В 15           07.06.2024           3
# 2  8 этаж        В 25 СС           09.06.2024          96
# 3                   В 25           11.06.2024         1,5
# 4                   В 15           07.06.2024         2,5
# 5  1 этаж           В 25           07.06.2024         191
#
#   application_submission_date application_submission_time
# 1                  06.06.2024                          15
# 2                  06.06.2024                          15
# 3                  06.06.2024                          19
# 4                  07.06.2024                           8
# 5                  07.06.2024                           9

# %%
df_completed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4100 entries, 1 to 4701
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   planned_delivery_date        4100 non-null   object
#  1   planned_delivery_time        4100 non-null   object
#  2   type                         4092 non-null   object
#  3   material                     4100 non-null   object
#  4   mobility                     2634 non-null   object
#  5   volume                       4100 non-null   object
#  6   full_name                    4091 non-null   object
#  7   phone                        4092 non-null   object
#  8   object                       4100 non-null   object
#  9   position                     4100 non-null   object
#  10  block                        4100 non-null   object
#  11  constructive                 4100 non-null   object
#  12  floor                        4100 non-null   object
#  13  material_class               4100 non-null   object
#  14  actual_delivery_date         4097 non-null   object
#  15  fact_volume                  4098 non-null   object
#  16  application_submission_date  4100 non-null   object
#  17  application_submission_time  4100 non-null   object
# dtypes: object(18)
# memory usage: 608.6+ KB

# %%
df_completed['planned_delivery_date'] = pd.to_datetime(df_completed['planned_delivery_date'], format='%d.%m.%Y')
df_completed['actual_delivery_date'] = pd.to_datetime(df_completed['actual_delivery_date'], format='%d.%m.%Y')
df_completed['application_submission_date'] = pd.to_datetime(df_completed['application_submission_date'], format='%d.%m.%Y')
df_completed['delivery_gap_days'] = (df_completed['planned_delivery_date'] - df_completed['application_submission_date']).dt.days
df_completed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4100 entries, 1 to 4701
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   planned_delivery_date        4100 non-null   datetime64[ns]
#  1   planned_delivery_time        4100 non-null   object
#  2   type                         4092 non-null   object
#  3   material                     4100 non-null   object
#  4   mobility                     2634 non-null   object
#  5   volume                       4100 non-null   object
#  6   full_name                    4091 non-null   object
#  7   phone                        4092 non-null   object
#  8   object                       4100 non-null   object
#  9   position                     4100 non-null   object
#  10  block                        4100 non-null   object
#  11  constructive                 4100 non-null   object
#  12  floor                        4100 non-null   object
#  13  material_class               4100 non-null   object
#  14  actual_delivery_date         4097 non-null   datetime64[ns]
#  15  fact_volume                  4098 non-null   object
#  16  application_submission_date  4100 non-null   datetime64[ns]
#  17  application_submission_time  4100 non-null   object
#  18  delivery_gap_days            4100 non-null   int64
# dtypes: datetime64[ns](3), int64(1), object(15)
# memory usage: 640.6+ KB

# %%
df_completed.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  Благоустройство    Бетон
# 2            2024-06-07                     8           Здание    Бетон
# 3            2024-06-07                     9           Здание    Бетон
# 4            2024-06-07                     9  Благоустройство    Бетон
# 5            2024-06-07                     8           Здание    Бетон
#
#   mobility volume        full_name        phone  \
# 1       П3      3  Нуршабаев Манат   7763030297
# 2       П4     90    Адаменко О.Ю.  87771456752
# 3       П4      2       Алинов К.М  87051854684
# 4       П3    2,5  Нуршабаев Манат   7763030297
# 5       П3    160         Масхут.Б  87051506578
#
#                               object position block       constructive  \
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
# 5                        Нурлы Жол 3   поз.64                 Вертикал
#
#     floor material_class actual_delivery_date fact_volume  \
# 1                   В 15           2024-06-07           3
# 2  8 этаж        В 25 СС           2024-06-09          96
# 3                   В 25           2024-06-11         1,5
# 4                   В 15           2024-06-07         2,5
# 5  1 этаж           В 25           2024-06-07         191
#
#   application_submission_date application_submission_time  delivery_gap_days  \
# 1                  2024-06-06                          15                  1
# 2                  2024-06-06                          15                  1
# 3                  2024-06-06                          19                  1
# 4                  2024-06-07                           8                  0
# 5                  2024-06-07                           9                  0
#
#    delay_days
# 1         0.0
# 2         2.0
# 3         4.0
# 4         0.0
# 5         0.0

# %%
df_completed['delay_days'] = (df_completed['actual_delivery_date'] - df_completed['planned_delivery_date']).dt.days
df_completed.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  Благоустройство    Бетон
# 2            2024-06-07                     8           Здание    Бетон
# 3            2024-06-07                     9           Здание    Бетон
# 4            2024-06-07                     9  Благоустройство    Бетон
# 5            2024-06-07                     8           Здание    Бетон
#
#   mobility volume        full_name        phone  \
# 1       П3      3  Нуршабаев Манат   7763030297
# 2       П4     90    Адаменко О.Ю.  87771456752
# 3       П4      2       Алинов К.М  87051854684
# 4       П3    2,5  Нуршабаев Манат   7763030297
# 5       П3    160         Масхут.Б  87051506578
#
#                               object position block       constructive  \
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
# 5                        Нурлы Жол 3   поз.64                 Вертикал
#
#     floor material_class actual_delivery_date fact_volume  \
# 1                   В 15           2024-06-07           3
# 2  8 этаж        В 25 СС           2024-06-09          96
# 3                   В 25           2024-06-11         1,5
# 4                   В 15           2024-06-07         2,5
# 5  1 этаж           В 25           2024-06-07         191
#
#   application_submission_date application_submission_time  delivery_gap_days  \
# 1                  2024-06-06                          15                  1
# 2                  2024-06-06                          15                  1
# 3                  2024-06-06                          19                  1
# 4                  2024-06-07                           8                  0
# 5                  2024-06-07                           9                  0
#
#    delay_days
# 1         0.0
# 2         2.0
# 3         4.0
# 4         0.0
# 5         0.0

# %%
df_completed[df_completed['type'].isna()]
# Out:
#      planned_delivery_date planned_delivery_time type material mobility  \
# 98              2024-06-30                     8  NaN    Бетон      NaN
# 193             2024-07-31                     8  NaN    Бетон      NaN
# 194             2024-07-31                     8  NaN    Бетон      NaN
# 197             2024-07-31                     8  NaN  Раствор      NaN
# 198             2024-07-31                     8  NaN  Раствор      NaN
# 412             2024-08-31                     8  NaN  Раствор      NaN
# 733             2024-09-30                     8  NaN  Раствор      NaN
# 1008            2024-06-30                     8  NaN  Раствор      NaN
#
#      volume full_name phone                                         object  \
# 98     3468       NaN   NaN  Разница за месяц м/у эл.заявкой и отчётом бру
# 193     244       NaN   NaN  Разница за месяц м/у эл.заявкой и отчётом бру
# 194     244       NaN   NaN  Разница за месяц м/у эл.заявкой и отчётом бру
# 197      31       NaN   NaN  Разница за месяц м/у эл.заявкой и отчётом бру
# 198      31       NaN   NaN  Разница за месяц м/у эл.заявкой и отчётом бру
# 412      47       NaN   NaN  Разница за месяц м/у эл.заявкой и отчётом бру
# 733      33       NaN   NaN  Разница за месяц м/у эл.заявкой и отчётом бру
# 1008    397       NaN   NaN          Разница м/у эл.журналом и отчётом БРУ
#
#      position block constructive floor material_class actual_delivery_date  \
# 98                                                              2024-06-30
# 193                                                             2024-07-31
# 194                                                             2024-07-31
# 197                                                             2024-07-31
# 198                                                             2024-07-31
# 412                                                             2024-08-31
# 733                                                             2024-09-30
# 1008                                                                   NaT
#
#      fact_volume application_submission_date application_submission_time  \
# 98          3468                  2024-06-30                           0
# 193          244                  2024-07-31                           0
# 194        31,00                  2024-07-31                           0
# 197          244                  2024-07-31                           0
# 198        31,00                  2024-07-31                           0
# 412        47,00                  2024-08-31                           0
# 733        33,00                  2024-09-30                           0
# 1008      397,00                  2024-11-27                           0
#
#       delivery_gap_days  delay_days
# 98                    0         0.0
# 193                   0         0.0
# 194                   0         0.0
# 197                   0         0.0
# 198                   0         0.0
# 412                   0         0.0
# 733                   0         0.0
# 1008               -150         NaN

# %%
df_not_null_in_type = df_completed[~df_completed['type'].isna()]
df_not_null_in_type.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  Благоустройство    Бетон
# 2            2024-06-07                     8           Здание    Бетон
# 3            2024-06-07                     9           Здание    Бетон
# 4            2024-06-07                     9  Благоустройство    Бетон
# 5            2024-06-07                     8           Здание    Бетон
#
#   mobility volume        full_name        phone  \
# 1       П3      3  Нуршабаев Манат   7763030297
# 2       П4     90    Адаменко О.Ю.  87771456752
# 3       П4      2       Алинов К.М  87051854684
# 4       П3    2,5  Нуршабаев Манат   7763030297
# 5       П3    160         Масхут.Б  87051506578
#
#                               object position block       constructive  \
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
# 5                        Нурлы Жол 3   поз.64                 Вертикал
#
#     floor material_class actual_delivery_date fact_volume  \
# 1                   В 15           2024-06-07           3
# 2  8 этаж        В 25 СС           2024-06-09          96
# 3                   В 25           2024-06-11         1,5
# 4                   В 15           2024-06-07         2,5
# 5  1 этаж           В 25           2024-06-07         191
#
#   application_submission_date application_submission_time  delivery_gap_days  \
# 1                  2024-06-06                          15                  1
# 2                  2024-06-06                          15                  1
# 3                  2024-06-06                          19                  1
# 4                  2024-06-07                           8                  0
# 5                  2024-06-07                           9                  0
#
#    delay_days
# 1         0.0
# 2         2.0
# 3         4.0
# 4         0.0
# 5         0.0

# %%
df_not_null_in_type.loc[:, 'type'] = df_not_null_in_type['type'].str.lower()
df_not_null_in_type.loc[:, 'type'] = df_not_null_in_type['type'].replace('здания', 'здание')
df_not_null_in_type['type'].unique()
# Out:
# array(['благоустройство', 'здание', 'коммерческие объекты',
#        'инженерные сети', 'производственные объекты', 'жби',
#        'реализация на сторону'], dtype=object)

# %%
df_not_null_in_type.loc[:, 'material'] = df_not_null_in_type['material'].str.lower()
df_not_null_in_type['material'].unique()
# Out:
# array(['бетон', 'раствор'], dtype=object)

# %%
print(df_not_null_in_type['mobility'].unique())
# Out:
# ['П3' 'П4' nan]

# %%
df_not_null_in_type.loc[:, 'mobility'] = df_not_null_in_type['mobility'].fillna('нет')
print(df_not_null_in_type['mobility'].unique())
# Out:
# ['П3' 'П4' 'нет']

# %%
df_not_null_in_type['volume'].unique()
# Out:
# array(['3', '90', '2', '2,5', '160', '28', '91', '20', '14', '106', '1,5',
#        '145', '103', '0,5', '115', '80', '118', '7', '4', '104', '25',
#        '11', '0,7', '52', '10', '1', '97', '30', '0,8', '13', '1,2', '95',
#        '98', '16,5', '6', '65', '94', '82', '34,5', '4,5', '105', '3,5',
#        '92', '70', '120', '38', '5', '12,5', '105,5', '114', '169', '140',
#        '6,5', '2,75', '19', '5,5', '60', '37', '15', '55', '21,5', '85',
#        '8', '74', '6,75', '113', '1,75', '4,75', '27,5', '2,25', '0,25',
#        '27', '168', '9', '4,25', '26,5', '11,5', '0,75', '17', '0,3',
#        '69', '12', '45', '15,5', '3,25', '16', '112', '10,5', '75', '18',
#        '33', '1,25', '585', '35', '560', '40', '16,7', '9,1', '8,4',
#        '116', '125', '7,2', '2,2', '19,2', '32', '72', '3,75', '62',
#        '88,4', '200', '24', '8,3', '155', '19,5', '180', '21', '9,5',
#        '7,5', '220', '22', '2,3', '3,1', '26', '110', '61', '48', '96',
#        '44', '8,5', '1,7', '1,1', '1,3', '2,7', '1,4', '31', '42', '3,6',
#        '89,5', '93,5', '15,3', '58,5', '17,5', '50', '43', '9,2', '8,2',
#        '23', '130', '465,4', '382,2', '3970,2', '10001,3', '10264,9',
#        '119,1', '14,5', '99', '41', '100', '0,4', '29', '93', '39', '0,9',
#        '119', '51', '1,6', '0,05', '0,6', '54', '9,3', '5,25', '7,25',
#        '6,25', '5,75', '7,75', '40,5', '47', '15,2', '2,8', '107', '138',
#        '6,2', '88', '84', '3,3', '25,352', '1,531', '3,8', '86', '4,8',
#        '150', '9,25', '128', '25,4', '8,75', '2,1', '900', '24,5', '165',
#        '18,5', '18,3', '127', '12,7', '10,75', '22,5', '13,5', '176',
#        '39,5', '24,6', '1,8', '14,2', '135', '1100', '16,75', '9,75',
#        '34', '10,8', '28,5', '20,7', '8,25', '19,3', '600', '147', '4,7',
#        '5,2', '212', '36', '28,1', '6,3', '5,6', '23,5', '5,1', '4,4',
#        '28,6', '6,4', '3,7', '10,25', '4,9', '0,1', '6,8', '21,8', '6,9',
#        '1.75', '1.5', '0.5', '6.5', '2.5', '254', '7,3'], dtype=object)

# %%
df_not_null_in_type[df_not_null_in_type['volume'] == '3970,2']
# Out:
#      planned_delivery_date planned_delivery_time    type material mobility  \
# 1738            2024-03-31                     8  здание    бетон       П3
#
#       volume full_name phone          object position block constructive  \
# 1738  3970,2       +++   +++  Общий за месяц
#
#      floor material_class actual_delivery_date fact_volume  \
# 1738                 В 15           2024-03-31      3970,2
#
#      application_submission_date application_submission_time  \
# 1738                  2024-10-09                          10
#
#       delivery_gap_days  delay_days
# 1738               -192         0.0

# %%
df_not_null_in_type[df_not_null_in_type['object'] == 'Общий за месяц']
# Out:
#      planned_delivery_date planned_delivery_time    type material mobility  \
# 1736            2024-01-31                     8  здание    бетон       П3
# 1737            2024-02-29                     8  здание    бетон       П3
# 1738            2024-03-31                     8  здание    бетон       П3
# 1741            2024-04-30                     8  здание    бетон       П3
# 1743            2024-05-31                     8  здание    бетон       П3
#
#        volume full_name phone          object position block constructive  \
# 1736    465,4       +++   +++  Общий за месяц
# 1737    382,2       +++   +++  Общий за месяц
# 1738   3970,2       +++   +++  Общий за месяц
# 1741  10001,3       +++   +++  Общий за месяц
# 1743  10264,9       +++   +++  Общий за месяц
#
#      floor material_class actual_delivery_date fact_volume  \
# 1736                 В 15           2024-01-31       465,4
# 1737                 В 15           2024-02-29       382,2
# 1738                 В 15           2024-03-31      3970,2
# 1741                 В 15           2024-04-30     10001,3
# 1743                 В 15           2024-05-31     10264,9
#
#      application_submission_date application_submission_time  \
# 1736                  2024-10-09                          10
# 1737                  2024-10-09                          10
# 1738                  2024-10-09                          10
# 1741                  2024-10-09                          10
# 1743                  2024-10-09                          10
#
#       delivery_gap_days  delay_days
# 1736               -252         0.0
# 1737               -223         0.0
# 1738               -192         0.0
# 1741               -162         0.0
# 1743               -131         0.0

# %%
df_since_june2024 = df_not_null_in_type[df_not_null_in_type['full_name'] != '+++']
df_since_june2024.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  благоустройство    бетон
# 2            2024-06-07                     8           здание    бетон
# 3            2024-06-07                     9           здание    бетон
# 4            2024-06-07                     9  благоустройство    бетон
# 5            2024-06-07                     8           здание    бетон
#
#   mobility volume        full_name        phone  \
# 1       П3      3  Нуршабаев Манат   7763030297
# 2       П4     90    Адаменко О.Ю.  87771456752
# 3       П4      2       Алинов К.М  87051854684
# 4       П3    2,5  Нуршабаев Манат   7763030297
# 5       П3    160         Масхут.Б  87051506578
#
#                               object position block       constructive  \
# 1  Благоустройство Школа (Нурлы Жол)                 Устройство бордюр
# 2                              СПОРТ   поз.74                 Вертикал
# 3                    Школа Нурлы Жол                  Световые приямки
# 4              Благоустройство СПОРТ                 Устройство бордюр
# 5                        Нурлы Жол 3   поз.64                 Вертикал
#
#     floor material_class actual_delivery_date fact_volume  \
# 1                   В 15           2024-06-07           3
# 2  8 этаж        В 25 СС           2024-06-09          96
# 3                   В 25           2024-06-11         1,5
# 4                   В 15           2024-06-07         2,5
# 5  1 этаж           В 25           2024-06-07         191
#
#   application_submission_date application_submission_time  delivery_gap_days  \
# 1                  2024-06-06                          15                  1
# 2                  2024-06-06                          15                  1
# 3                  2024-06-06                          19                  1
# 4                  2024-06-07                           8                  0
# 5                  2024-06-07                           9                  0
#
#    delay_days
# 1         0.0
# 2         2.0
# 3         4.0
# 4         0.0
# 5         0.0

# %%
df_since_june2024['volume'].unique()
# Out:
# array(['3', '90', '2', '2,5', '160', '28', '91', '20', '14', '106', '1,5',
#        '145', '103', '0,5', '115', '80', '118', '7', '4', '104', '25',
#        '11', '0,7', '52', '10', '1', '97', '30', '0,8', '13', '1,2', '95',
#        '98', '16,5', '6', '65', '94', '82', '34,5', '4,5', '105', '3,5',
#        '92', '70', '120', '38', '5', '12,5', '105,5', '114', '169', '140',
#        '6,5', '2,75', '19', '5,5', '60', '37', '15', '55', '21,5', '85',
#        '8', '74', '6,75', '113', '1,75', '4,75', '27,5', '2,25', '0,25',
#        '27', '168', '9', '4,25', '26,5', '11,5', '0,75', '17', '0,3',
#        '69', '12', '45', '15,5', '3,25', '16', '112', '10,5', '75', '18',
#        '33', '1,25', '585', '35', '560', '40', '16,7', '9,1', '8,4',
#        '116', '125', '7,2', '2,2', '19,2', '32', '72', '3,75', '62',
#        '88,4', '200', '24', '8,3', '155', '19,5', '180', '21', '9,5',
#        '7,5', '220', '22', '2,3', '3,1', '26', '110', '61', '48', '96',
#        '44', '8,5', '1,7', '1,1', '1,3', '2,7', '1,4', '31', '42', '3,6',
#        '89,5', '93,5', '15,3', '58,5', '17,5', '50', '43', '9,2', '8,2',
#        '23', '130', '14,5', '99', '41', '100', '0,4', '29', '93', '39',
#        '0,9', '119', '51', '1,6', '0,05', '0,6', '54', '9,3', '5,25',
#        '7,25', '6,25', '5,75', '7,75', '40,5', '47', '15,2', '2,8', '107',
#        '138', '6,2', '88', '84', '3,3', '25,352', '1,531', '3,8', '86',
#        '4,8', '150', '9,25', '128', '25,4', '8,75', '2,1', '900', '24,5',
#        '165', '18,5', '18,3', '127', '12,7', '10,75', '22,5', '13,5',
#        '176', '39,5', '24,6', '1,8', '14,2', '135', '1100', '16,75',
#        '9,75', '34', '10,8', '28,5', '20,7', '8,25', '19,3', '600', '147',
#        '4,7', '5,2', '212', '36', '28,1', '6,3', '5,6', '23,5', '5,1',
#        '4,4', '28,6', '6,4', '3,7', '10,25', '4,9', '0,1', '6,8', '21,8',
#        '6,9', '1.75', '1.5', '0.5', '6.5', '2.5', '254', '7,3'],
#       dtype=object)

# %%
df_since_june2024.loc[:, 'volume'] = df_since_june2024['volume'].str.split(' ').str[0]
df_since_june2024['volume'].unique()
# Out:
# array(['3', '90', '2', '2,5', '160', '28', '91', '20', '14', '106', '1,5',
#        '145', '103', '0,5', '115', '80', '118', '7', '4', '104', '25',
#        '11', '0,7', '52', '10', '1', '97', '30', '0,8', '13', '1,2', '95',
#        '98', '16,5', '6', '65', '94', '82', '34,5', '4,5', '105', '3,5',
#        '92', '70', '120', '38', '5', '12,5', '105,5', '114', '169', '140',
#        '6,5', '2,75', '19', '5,5', '60', '37', '15', '55', '21,5', '85',
#        '8', '74', '6,75', '113', '1,75', '4,75', '27,5', '2,25', '0,25',
#        '27', '168', '9', '4,25', '26,5', '11,5', '0,75', '17', '0,3',
#        '69', '12', '45', '15,5', '3,25', '16', '112', '10,5', '75', '18',
#        '33', '1,25', '585', '35', '560', '40', '16,7', '9,1', '8,4',
#        '116', '125', '7,2', '2,2', '19,2', '32', '72', '3,75', '62',
#        '88,4', '200', '24', '8,3', '155', '19,5', '180', '21', '9,5',
#        '7,5', '220', '22', '2,3', '3,1', '26', '110', '61', '48', '96',
#        '44', '8,5', '1,7', '1,1', '1,3', '2,7', '1,4', '31', '42', '3,6',
#        '89,5', '93,5', '15,3', '58,5', '17,5', '50', '43', '9,2', '8,2',
#        '23', '130', '14,5', '99', '41', '100', '0,4', '29', '93', '39',
#        '0,9', '119', '51', '1,6', '0,05', '0,6', '54', '9,3', '5,25',
#        '7,25', '6,25', '5,75', '7,75', '40,5', '47', '15,2', '2,8', '107',
#        '138', '6,2', '88', '84', '3,3', '25,352', '1,531', '3,8', '86',
#        '4,8', '150', '9,25', '128', '25,4', '8,75', '2,1', '900', '24,5',
#        '165', '18,5', '18,3', '127', '12,7', '10,75', '22,5', '13,5',
#        '176', '39,5', '24,6', '1,8', '14,2', '135', '1100', '16,75',
#        '9,75', '34', '10,8', '28,5', '20,7', '8,25', '19,3', '600', '147',
#        '4,7', '5,2', '212', '36', '28,1', '6,3', '5,6', '23,5', '5,1',
#        '4,4', '28,6', '6,4', '3,7', '10,25', '4,9', '0,1', '6,8', '21,8',
#        '6,9', '1.75', '1.5', '0.5', '6.5', '2.5', '254', '7,3'],
#       dtype=object)

# %%
df_since_june2024 = df_since_june2024.copy()
df_since_june2024['volume'] = df_since_june2024['volume'].str.replace(',', '.', regex=False).astype(float)
df_since_june2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4084 entries, 1 to 4701
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   planned_delivery_date        4084 non-null   datetime64[ns]
#  1   planned_delivery_time        4084 non-null   object
#  2   type                         4084 non-null   object
#  3   material                     4084 non-null   object
#  4   mobility                     4084 non-null   object
#  5   volume                       4084 non-null   float64
#  6   full_name                    4083 non-null   object
#  7   phone                        4084 non-null   object
#  8   object                       4084 non-null   object
#  9   position                     4084 non-null   object
#  10  block                        4084 non-null   object
#  11  constructive                 4084 non-null   object
#  12  floor                        4084 non-null   object
#  13  material_class               4084 non-null   object
#  14  actual_delivery_date         4082 non-null   datetime64[ns]
#  15  fact_volume                  4082 non-null   object
#  16  application_submission_date  4084 non-null   datetime64[ns]
#  17  application_submission_time  4084 non-null   object
#  18  delivery_gap_days            4084 non-null   int64
#  19  delay_days                   4082 non-null   float64
# dtypes: datetime64[ns](3), float64(2), int64(1), object(14)
# memory usage: 670.0+ KB

# %%
print(df_since_june2024['full_name'].nunique())
print(df_since_june2024['full_name'].unique())
# Out:
# 225
# ['Нуршабаев Манат' 'Адаменко О.Ю.' 'Алинов К.М' 'Масхут.Б'
#  'Баяхметов Ф.Е.' 'Мусаканов А.О' 'Кабден Ринат' 'Нуксарин СО'
#  'Нуксарин С О' 'Шестаков АЕ' 'Аубакиров Д.Ж.' 'Шестаков АЕ '
#  'Сейтказынов Д.А.' 'Адаменко Олег' 'Юшко ' 'Баяхметов ' 'ШМАКОВ.И' 'Юшко'
#  'Акылбеков Нариман' 'Баянбаев' 'Аменов Эльдар Айтжанович'
#  'Рахимжанов Арман ' 'Алинов К' 'Адаменко Олень' 'Азимхан Б.Е.'
#  'Баянбаев Е.Д' 'Турсынбеков Х.Г. ' 'Киселев Д.В.' 'Абдрахманов Е.Т.'
#  'Азимхан Б.Е' 'Кабдиев М' 'Оразбеков Е.К' 'Грибченко.Е.И' 'Шестаков '
#  'Шматов Д.П.' 'Азимхан Б,Е' 'Грибченко Е.И.' 'Грибченко Е.И' 'Баяхметов'
#  'Юшко С.В.' 'Дүйсен Ільяс Ержанұлы' 'Юшко. С.В' 'Грибченко Е.И '
#  'Юшко.С.В' 'Абдрахманов Д.К' 'Акимбеков Р.С' 'Ерболатов ' 'Сагадиев.А.Р'
#  'Кабден Р' 'Маутбеков' 'Титаренко Кирилл Владимирович' 'Юшко С.В'
#  'Каширский Никита Сергеевич' 'Маутбеков С' 'Юшко.С.В.' 'Масалимов Айбек'
#  'Акимбеков Р.С.' 'Масалимов' 'Юшко.С' 'Макажанов Е.С' 'Титаренко Кирилл'
#  'Макажанов Е.С.' 'Алимжанов Куантай Болатович' 'Лебедев' 'Юшко. С'
#  'Юшко. С. ' 'бру' 'Адаменко' 'ГАНЖИЕВ ИП' 'БРУ'
#  'Алимжанов Куантай Болатович ' 'Плахуты 68' 'Славского 28' 'РазведПРОМ'
#  'Вейкай' 'Грибченко.Евгений.Иванович' 'Пескабетон ' 'Мейрам'
#  'Алимжанов Куантай  Болатович ' 'Юшко. С ' 'Юшко С' 'Частное лицо'
#  'Жастар,Утепова,Энтузиастов' 'ДСУ-11 28мкр' 'Габдиев М.Э.' 'Сидоров'
#  'ДСУ-11' 'Абдрахманов Е.Т' 'Юшко С ' 'Ерболатов Е' 'Акимбеков РС'
#  'Рижская14/2 Дом сруб' 'леваневского 23 ДСУ 11' 'Ахметова'
#  'QazConstructions' 'Юшко  С' 'Оразбеков' 'Саматов С' 'Акимбеков'
#  'Танабаев Т.К.' 'Ақылбеков Н' 'Токтаров Султан' 'Фирма_Азия'
#  'Акимбеков Р С' 'Сарсекеев Т' 'Енсебаев.Б.Т' 'Бимаканов М'
#  'Абдрахманов Д.К ' 'ОскеменАгроПродукт' 'Шматов Д. П.' 'Шестаков А'
#  'Грибченко.Е,И' 'Носикова 67/1' 'Оразбеков Ержан С' 'Оразбеков Ержан'
#  'Алимжанов К.Б.' nan 'Оразбеков Е.К.' 'Векай' 'Оразбеков Е' 'Касенов А'
#  'Мусин Т.М' 'Эльдар ' 'Акимбеков Р' 'Тоқтарханов А.Н.' 'Урумбаев.А.Т'
#  'ДСУ11' 'Шестаков' 'Куатбеков Елнур Думанулы' 'Куатбеков Елнур'
#  'Белоусов Б' 'Мусин Т.Н' 'Жакежанов Диас Ерболұлы'
#  'Жаксылыков Бакытжан Каппарович ' 'Ерболатов'
#  'Грибченко Евгений Иванович' 'Мусин Т.Н.' 'Абдрахманов '
#  'Жаксылыков Бакытжан Каппарович' 'Муктаров Темрлан' 'дсу 11' 'Енсебаев.Б'
#  'Енсебаев Б.Т.' 'Шестаков А.Е' 'Шестаков .А.Е' 'Аяпбергенов ' 'Дешин'
#  'Дешин Александр ' 'Жаксылыков Б К' 'Раимханов Р.' 'Титаренко Кирилл '
#  'Бейсембинов' 'Дешин ' 'Жаксылыков Б' 'Тілеуқанов Жалғас'
#  'Садуакасов .О.Д' 'Сериков А' 'Жаманов Д О' 'Акимбеков. Р' 'Сериков Д'
#  'Сериков  А' 'Алланиязов Колдас Оранбаевич ' 'Сериков А ' 'Адаменко О'
#  'Масалимов А' 'Жакежанов диас' 'Бейсембинов Канат Серикович'
#  'Тоқтасынов Ә' 'Мусин' 'Алинов ' 'Алланиязов Колдас Орынбаевич '
#  'Саметаев Амантай ' 'Саметаев А' 'Пайзрахманов Д' 'Енсебаев.Б.Т '
#  'Алланиязов К.О.' 'Алинов' 'Саметаев ' 'Юмаев Александр ' 'Салангин'
#  'Салангин ' 'Нурахметов ' 'Пайзрахманов д' 'Мырзахметов Б' 'Енсебаев.А.Т'
#  'Жотабаев Рустам' 'Муратханов Мерей' 'Мусин ' 'Саметаев АЕ' 'Юшко.с '
#  'Урумбаев. А.Т' 'Камалов Ш.О. ' 'Муратханов'
#  'Бейсембинов Канат Серикович ' 'Камалов Шыңғыс'
#  'Камалов Шыңғыс Ветлаборатория' 'Аяпбергенов' 'Абдрахманов Д'
#  'Туркестанов' 'Амренов Э' 'Абдрахманов Е ' 'Туркестанов М.К.'
#  'Титаренко К' 'Титаренко Кирил' 'Кизатулин к.с' 'Кизатулин' 'Кизатулин.'
#  'Сагадиев Алибек' 'Аубакиров Дидар ' 'Азимхан' 'Cаматов С' 'Масхут Б'
#  'Аубакиров' 'Киселев' 'Аубакиров Д' 'Манат Нуршабаев' 'Токтаров С'
#  'Ақылбеков Нариман' 'Тоқтаров С' 'азимхан' 'Турсынбеков х.г.'
#  'Титоренко К' 'Ақылбеков Нариман ' 'Манат нұршабаев' 'Манат Нұршабаев'
#  'Абылов Ерасыл']

# %%
df_since_june2024['full_name'] = df_since_june2024['full_name'].str.lower()
df_since_june2024['full_name'] = df_since_june2024['full_name'].str.strip()
df_since_june2024['full_name'] = df_since_june2024['full_name'].str.split(' ').str[0]
df_since_june2024['full_name'] = np.where(df_since_june2024['type'] == 'реализация на сторону', 
                                          np.nan,
                                          df_since_june2024['full_name'])
df_since_june2024['full_name'] = df_since_june2024['full_name'].fillna('на сторону')
df_since_june2024['full_name'] = df_since_june2024['full_name'].str.split(r'[.,]').str[0]
print(df_since_june2024['full_name'].nunique())
sorted(list(df_since_june2024['full_name'].unique()))
# Out:
# 81
# ['cаматов',
#  'абдрахманов',
#  'абылов',
#  'адаменко',
#  'азимхан',
#  'акимбеков',
#  'акылбеков',
#  'алимжанов',
#  'алинов',
#  'алланиязов',
#  'аменов',
#  'амренов',
#  'аубакиров',
#  'аяпбергенов',
#  'ақылбеков',
#  'баянбаев',
#  'баяхметов',
#  'бейсембинов',
#  'белоусов',
#  'бимаканов',
#  'бру',
#  'габдиев',
#  'грибченко',
#  'дешин',
#  'дүйсен',
#  'енсебаев',
#  'ерболатов',
#  'жакежанов',
#  'жаксылыков',
#  'жаманов',
#  'жотабаев',
#  'кабден',
#  'кабдиев',
#  'камалов',
#  'каширский',
#  'кизатулин',
#  'киселев',
#  'куатбеков',
#  'лебедев',
#  'макажанов',
#  'манат',
#  'масалимов',
#  'масхут',
#  'маутбеков',
#  'мейрам',
#  'муктаров',
#  'муратханов',
#  'мусаканов',
#  'мусин',
#  'мырзахметов',
#  'на сторону',
#  'нуксарин',
#  'нурахметов',
#  'нуршабаев',
#  'оразбеков',
#  'пайзрахманов',
#  'раимханов',
#  'рахимжанов',
#  'сагадиев',
#  'салангин',
#  'саматов',
#  'саметаев',
#  'сарсекеев',
#  'сейтказынов',
#  'сериков',
#  'танабаев',
#  'титаренко',
#  'титоренко',
#  'токтаров',
#  'тоқтаров',
#  'тоқтарханов',
#  'тоқтасынов',
#  'туркестанов',
#  'турсынбеков',
#  'тілеуқанов',
#  'урумбаев',
#  'шестаков',
#  'шмаков',
#  'шматов',
#  'юмаев',
#  'юшко']

# %%
df_since_june2024['object'] = (
    df_since_june2024['object']
    .str.lower()
    .str.strip()
    .str.replace(r'\s*-\s*', '-', regex=True)
    .str.replace(r'\s+', ' ', regex=True)
)
print(df_since_june2024['object'].nunique())
sorted(list(df_since_june2024['object'].unique()))
# Out:
# 109
# ['',
#  '4 бру',
#  'brick town',
#  'brick town 2',
#  'royal b',
#  'абк',
#  'абк ново-явленка',
#  'абк ново-явленка база',
#  'абк(ново-явленка',
#  'абк(ново-явленка)',
#  'автомойка (сатпаева 82а)',
#  'автомойка ул. сатпаева 82а',
#  'автомока ул. сатпаева 82 а',
#  'асфальтозавод (новоявленка)',
#  'атц победы',
#  'база ново-явленка. абз',
#  'база эскор',
#  'базовавя 5 тупик',
#  'базовая 5',
#  'базовая 5 (тупик)',
#  'базовая, 3',
#  'базовая, 3 магазин автозапчастей',
#  'бизнес-центр',
#  'бизнесцентр',
#  'благоустройства бру',
#  'благоустройство 12-16 этажки',
#  'благоустройство brick town',
#  'благоустройство комфортная школа (самрук)',
#  'благоустройство нурлы жол 1,2',
#  'благоустройство нурлы жол 3',
#  'благоустройство спорт',
#  'благоустройство школа (нурлы жол)',
#  'бру',
#  'бру 4',
#  'бру жансат',
#  'бру на растворный узел',
#  'бру парковка',
#  'бру под силос',
#  'бру столовая',
#  'гараж',
#  'гараж (на комсомольском)',
#  'гимназия(колледж)',
#  'глубоковский кирзавод',
#  'глубоковский кирзавод (складпод глину)',
#  'горная ульбинка',
#  'горноя ульбинка',
#  'двд собр',
#  'дет сад «мурагер»',
#  'детский сад мурагер',
#  'дробилка (новоявленка)',
#  'дсу 11 28 мкр',
#  'жби',
#  'жби 2',
#  'жби цех',
#  'жби,цех брусчатки,',
#  'жби-2',
#  'инженерные сети 12-16-этажки',
#  'инженерные сети брик таун',
#  'инженерные сети комфортная школа (самрук)',
#  'инженерные сети школа (нурлы жол)',
#  'карьер',
#  'карьер жансат',
#  'квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (нурлы жол 3)',
#  'квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (спорт)',
#  'кирзавод',
#  'клюшки поз 53',
#  'коллектор',
#  'комфортная школа',
#  'кос',
#  'кп ново-явленка',
#  'кренделия',
#  'ктп 72 поз',
#  'лабаратовия',
#  'лаборатория',
#  'ледовой каток',
#  'ледовый каток',
#  'лицей',
#  'магазин базовая, 3',
#  'магазин запчастей базовая, 3',
#  'магазин, базовая, 3',
#  'металлоцех (новое строительство)',
#  'мост (новоявленка)',
#  'ново-явленка база',
#  'нур-тау',
#  'нурлы жол 3',
#  'нұр тау',
#  'орленок',
#  'орлёнок',
#  'очистные сооружениякос согра',
#  'паркинг',
#  'пропарочная камера',
#  'садик мурагер',
#  'собр двд',
#  'спорт',
#  'тоо" глубоковский кирзавод "',
#  'тп',
#  'транспортная развязка на пересечении пр. сатпаева и ул. жибек жолы',
#  'тц победы',
#  'урунтаева 12/1',
#  'центральная база (сам.ш.29)',
#  'центральный склад (новое строительство)',
#  'цех брусчатки (базовая 5)',
#  'цех жби бозовая 5',
#  'цех на базовой 5',
#  'цех тротуарной плитки',
#  'школа нурлы жол',
#  'эко полис под башенный кран',
#  'эко полюс под кран подбетонка',
#  'экополис']

# %%
print(df_since_june2024['object'].value_counts().to_string())
# Out:
# object
# нурлы жол 3                                                                                895
# жби                                                                                        507
# спорт                                                                                      416
# brick town                                                                                 304
# комфортная школа                                                                           298
# royal b                                                                                    160
# благоустройство brick town                                                                 117
# орлёнок                                                                                    106
# благоустройство нурлы жол 3                                                                104
# центральная база (сам.ш.29)                                                                 98
# благоустройство комфортная школа (самрук)                                                   83
# транспортная развязка на пересечении пр. сатпаева и ул. жибек жолы                          78
# благоустройство школа (нурлы жол)                                                           75
#                                                                                             63
# кос                                                                                         62
# ледовый каток                                                                               62
# экополис                                                                                    59
# абк ново-явленка                                                                            53
# металлоцех (новое строительство)                                                            45
# жби-2                                                                                       44
# дробилка (новоявленка)                                                                      38
# квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (нурлы жол 3)     35
# центральный склад (новое строительство)                                                     32
# пропарочная камера                                                                          29
# абк                                                                                         27
# благоустройство спорт                                                                       25
# асфальтозавод (новоявленка)                                                                 24
# благоустройство нурлы жол 1,2                                                               23
# база эскор                                                                                  21
# жби цех                                                                                     20
# инженерные сети комфортная школа (самрук)                                                   11
# благоустройство 12-16 этажки                                                                10
# магазин базовая, 3                                                                           9
# горноя ульбинка                                                                              9
# кренделия                                                                                    8
# brick town 2                                                                                 8
# горная ульбинка                                                                              7
# инженерные сети брик таун                                                                    5
# карьер жансат                                                                                5
# садик мурагер                                                                                5
# глубоковский кирзавод                                                                        5
# цех тротуарной плитки                                                                        3
# бру столовая                                                                                 3
# карьер                                                                                       3
# бизнес-центр                                                                                 3
# инженерные сети школа (нурлы жол)                                                            3
# квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (спорт)            3
# бру                                                                                          3
# школа нурлы жол                                                                              3
# двд собр                                                                                     3
# собр двд                                                                                     3
# гараж                                                                                        2
# абк(ново-явленка)                                                                            2
# нур-тау                                                                                      2
# жби 2                                                                                        2
# тц победы                                                                                    2
# глубоковский кирзавод (складпод глину)                                                       2
# ледовой каток                                                                                2
# коллектор                                                                                    2
# мост (новоявленка)                                                                           2
# лицей                                                                                        2
# базовая 5                                                                                    2
# тп                                                                                           1
# бру 4                                                                                        1
# абк(ново-явленка                                                                             1
# кп ново-явленка                                                                              1
# эко полис под башенный кран                                                                  1
# лабаратовия                                                                                  1
# гараж (на комсомольском)                                                                     1
# база ново-явленка. абз                                                                       1
# эко полюс под кран подбетонка                                                                1
# бизнесцентр                                                                                  1
# паркинг                                                                                      1
# абк ново-явленка база                                                                        1
# кирзавод                                                                                     1
# лаборатория                                                                                  1
# атц победы                                                                                   1
# 4 бру                                                                                        1
# базовавя 5 тупик                                                                             1
# бру на растворный узел                                                                       1
# гимназия(колледж)                                                                            1
# урунтаева 12/1                                                                               1
# цех брусчатки (базовая 5)                                                                    1
# дет сад «мурагер»                                                                            1
# бру парковка                                                                                 1
# бру жансат                                                                                   1
# детский сад мурагер                                                                          1
# ново-явленка база                                                                            1
# клюшки поз 53                                                                                1
# магазин запчастей базовая, 3                                                                 1
# магазин, базовая, 3                                                                          1
# нұр тау                                                                                      1
# базовая, 3                                                                                   1
# цех на базовой 5                                                                             1
# тоо" глубоковский кирзавод "                                                                 1
# базовая, 3 магазин автозапчастей                                                             1
# базовая 5 (тупик)                                                                            1
# благоустройства бру                                                                          1
# жби,цех брусчатки,                                                                           1
# автомойка (сатпаева 82а)                                                                     1
# автомойка ул. сатпаева 82а                                                                   1
# дсу 11 28 мкр                                                                                1
# цех жби бозовая 5                                                                            1
# очистные сооружениякос согра                                                                 1
# автомока ул. сатпаева 82 а                                                                   1
# инженерные сети 12-16-этажки                                                                 1
# орленок                                                                                      1
# бру под силос                                                                                1
# ктп 72 поз                                                                                   1

# %%
df_since_june2024['object'] = df_since_june2024['object'].replace(
    ['жби-2', 'жби -2','жби цех','жби 2', 'жби,цех брусчатки,', 
     'цех брусчатки (базовая 5)', 'цех жби бозовая 5',
     'цех тротуарной плитки'], 'жби')
df_since_june2024['object'] = df_since_june2024['object'].replace(
    ['эко полис под башенный кран', 'эко полюс под кран подбетонка','паркинг'], 'экополис')
df_since_june2024['object'] = df_since_june2024['object'].replace(
     ['тц победы', 'бизнес-центр','бизнесцентр'], 'Бизнес центр пр.Победы')
print(df_since_june2024['object'].value_counts().to_string())
# Out:
# object
# нурлы жол 3                                                                                895
# жби                                                                                        579
# спорт                                                                                      416
# brick town                                                                                 304
# комфортная школа                                                                           298
# royal b                                                                                    160
# благоустройство brick town                                                                 117
# орлёнок                                                                                    106
# благоустройство нурлы жол 3                                                                104
# центральная база (сам.ш.29)                                                                 98
# благоустройство комфортная школа (самрук)                                                   83
# транспортная развязка на пересечении пр. сатпаева и ул. жибек жолы                          78
# благоустройство школа (нурлы жол)                                                           75
#                                                                                             63
# кос                                                                                         62
# экополис                                                                                    62
# ледовый каток                                                                               62
# абк ново-явленка                                                                            53
# металлоцех (новое строительство)                                                            45
# дробилка (новоявленка)                                                                      38
# квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (нурлы жол 3)     35
# центральный склад (новое строительство)                                                     32
# пропарочная камера                                                                          29
# абк                                                                                         27
# благоустройство спорт                                                                       25
# асфальтозавод (новоявленка)                                                                 24
# благоустройство нурлы жол 1,2                                                               23
# база эскор                                                                                  21
# инженерные сети комфортная школа (самрук)                                                   11
# благоустройство 12-16 этажки                                                                10
# горноя ульбинка                                                                              9
# магазин базовая, 3                                                                           9
# кренделия                                                                                    8
# brick town 2                                                                                 8
# горная ульбинка                                                                              7
# Бизнес центр пр.Победы                                                                       6
# инженерные сети брик таун                                                                    5
# карьер жансат                                                                                5
# глубоковский кирзавод                                                                        5
# садик мурагер                                                                                5
# школа нурлы жол                                                                              3
# бру                                                                                          3
# карьер                                                                                       3
# бру столовая                                                                                 3
# собр двд                                                                                     3
# двд собр                                                                                     3
# квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (спорт)            3
# инженерные сети школа (нурлы жол)                                                            3
# гараж                                                                                        2
# мост (новоявленка)                                                                           2
# абк(ново-явленка)                                                                            2
# ледовой каток                                                                                2
# коллектор                                                                                    2
# глубоковский кирзавод (складпод глину)                                                       2
# базовая 5                                                                                    2
# лицей                                                                                        2
# нур-тау                                                                                      2
# гараж (на комсомольском)                                                                     1
# лаборатория                                                                                  1
# абк(ново-явленка                                                                             1
# бру 4                                                                                        1
# база ново-явленка. абз                                                                       1
# бру на растворный узел                                                                       1
# кирзавод                                                                                     1
# тп                                                                                           1
# абк ново-явленка база                                                                        1
# 4 бру                                                                                        1
# лабаратовия                                                                                  1
# кп ново-явленка                                                                              1
# атц победы                                                                                   1
# тоо" глубоковский кирзавод "                                                                 1
# гимназия(колледж)                                                                            1
# бру под силос                                                                                1
# урунтаева 12/1                                                                               1
# дет сад «мурагер»                                                                            1
# бру парковка                                                                                 1
# бру жансат                                                                                   1
# детский сад мурагер                                                                          1
# ново-явленка база                                                                            1
# клюшки поз 53                                                                                1
# магазин запчастей базовая, 3                                                                 1
# магазин, базовая, 3                                                                          1
# нұр тау                                                                                      1
# базовая, 3                                                                                   1
# цех на базовой 5                                                                             1
# базовая, 3 магазин автозапчастей                                                             1
# базовавя 5 тупик                                                                             1
# базовая 5 (тупик)                                                                            1
# благоустройства бру                                                                          1
# автомойка (сатпаева 82а)                                                                     1
# автомойка ул. сатпаева 82а                                                                   1
# дсу 11 28 мкр                                                                                1
# очистные сооружениякос согра                                                                 1
# автомока ул. сатпаева 82 а                                                                   1
# инженерные сети 12-16-этажки                                                                 1
# орленок                                                                                      1
# ктп 72 поз                                                                                   1

# %%
for_boxplot = df_since_june2024['object'].value_counts().reset_index()
for_boxplot.columns = ['object', 'count']
plt.figure(figsize=(15,6))
sns.boxplot(for_boxplot[for_boxplot['count'] > 50], x='count')
plt.show()

# %%
objects = [
    'brick town',
    'brick town 2',
    'royal b',
    'автомойка атх',
    'автомойка (нурлы жол)',
    'асфальтозавод (новоявленка)',
    'база эскор',
    'благоустройство 12-16 этажки',
    'благоустройство brick town',
    'благоустройство нурлы жол 1,2',
    'благоустройство нурлы жол 3',
    'благоустройство спорт',
    'благоустройство школа (нурлы жол)',
    'благоустройство комфортная школа (самрук)',
    'дробилка (новоявленка)',
    'жби',
    'инженерные сети 12-16-этажки',
    'инженерные сети брик таун',
    'инженерные сети поз. 107',
    'инженерные сети  школа (нурлы жол)',
    'инженерные сети комфортная школа (самрук)',
    'инженерные сети школа нурлы жол',
    'каменный карьер',
    'кафе бистро',
    'квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (нурлы жол 1-2)',
    'квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (нурлы жол 3)',
    'квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (спорт)',
    'коллектор',
    'комфортная школа',
    'кос',
    'кренделия',
    'ледовый каток',
    'магазин автозапчастей (эскор)',
    'металлоцех (новое строительство)',
    'мост (новоявленка)',
    'нурлы жол 3',
    'орлёнок',
    'очистные сооружения',
    'пропарочная камера',
    'спорт',
    'транспортная развязка на пересечении пр. сатпаева и ул. жибек жолы',
    'транспортная развязка на пересечении пр. сатпаева и ул. жибек жолы',
    'центральная база (сам.ш.29)',
    'центральный склад (новое строительство)',
    'экополис' 
]

# %%
df_since_june2024['object'] = df_since_june2024['object'].apply(lambda x: x if x in objects else 'другой')
print(df_since_june2024['object'].value_counts().to_string())
# Out:
# object
# нурлы жол 3                                                                                895
# жби                                                                                        579
# спорт                                                                                      416
# brick town                                                                                 304
# комфортная школа                                                                           298
# другой                                                                                     263
# royal b                                                                                    160
# благоустройство brick town                                                                 117
# орлёнок                                                                                    106
# благоустройство нурлы жол 3                                                                104
# центральная база (сам.ш.29)                                                                 98
# благоустройство комфортная школа (самрук)                                                   83
# транспортная развязка на пересечении пр. сатпаева и ул. жибек жолы                          78
# благоустройство школа (нурлы жол)                                                           75
# кос                                                                                         62
# ледовый каток                                                                               62
# экополис                                                                                    62
# металлоцех (новое строительство)                                                            45
# дробилка (новоявленка)                                                                      38
# квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (нурлы жол 3)     35
# центральный склад (новое строительство)                                                     32
# пропарочная камера                                                                          29
# благоустройство спорт                                                                       25
# асфальтозавод (новоявленка)                                                                 24
# благоустройство нурлы жол 1,2                                                               23
# база эскор                                                                                  21
# инженерные сети комфортная школа (самрук)                                                   11
# благоустройство 12-16 этажки                                                                10
# кренделия                                                                                    8
# brick town 2                                                                                 8
# инженерные сети брик таун                                                                    5
# квартальные инженерные сети теплоснабжения, водоснабжения и водоотведения (спорт)            3
# мост (новоявленка)                                                                           2
# коллектор                                                                                    2
# инженерные сети 12-16-этажки                                                                 1

# %%
df_since_june2024.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  благоустройство    бетон
# 2            2024-06-07                     8           здание    бетон
# 3            2024-06-07                     9           здание    бетон
# 4            2024-06-07                     9  благоустройство    бетон
# 5            2024-06-07                     8           здание    бетон
#
#   mobility  volume  full_name        phone                             object  \
# 1       П3     3.0  нуршабаев   7763030297  благоустройство школа (нурлы жол)
# 2       П4    90.0   адаменко  87771456752                              спорт
# 3       П4     2.0     алинов  87051854684                             другой
# 4       П3     2.5  нуршабаев   7763030297              благоустройство спорт
# 5       П3   160.0     масхут  87051506578                        нурлы жол 3
#
#   position block       constructive   floor material_class  \
# 1                 Устройство бордюр                   В 15
# 2   поз.74                 Вертикал  8 этаж        В 25 СС
# 3                  Световые приямки                   В 25
# 4                 Устройство бордюр                   В 15
# 5   поз.64                 Вертикал  1 этаж           В 25
#
#   actual_delivery_date fact_volume application_submission_date  \
# 1           2024-06-07           3                  2024-06-06
# 2           2024-06-09          96                  2024-06-06
# 3           2024-06-11         1,5                  2024-06-06
# 4           2024-06-07         2,5                  2024-06-07
# 5           2024-06-07         191                  2024-06-07
#
#   application_submission_time  delivery_gap_days  delay_days
# 1                          15                  1         0.0
# 2                          15                  1         2.0
# 3                          19                  1         4.0
# 4                           8                  0         0.0
# 5                           9                  0         0.0

# %%
df_since_june2024['delay'] =  df_since_june2024['delay_days'].apply(lambda x: 0 if x == 0 else 1)
df_since_june2024.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  благоустройство    бетон
# 2            2024-06-07                     8           здание    бетон
# 3            2024-06-07                     9           здание    бетон
# 4            2024-06-07                     9  благоустройство    бетон
# 5            2024-06-07                     8           здание    бетон
#
#   mobility  volume  full_name        phone                             object  \
# 1       П3     3.0  нуршабаев   7763030297  благоустройство школа (нурлы жол)
# 2       П4    90.0   адаменко  87771456752                              спорт
# 3       П4     2.0     алинов  87051854684                             другой
# 4       П3     2.5  нуршабаев   7763030297              благоустройство спорт
# 5       П3   160.0     масхут  87051506578                        нурлы жол 3
#
#   position  ...       constructive   floor material_class  \
# 1           ...  Устройство бордюр                   В 15
# 2   поз.74  ...           Вертикал  8 этаж        В 25 СС
# 3           ...   Световые приямки                   В 25
# 4           ...  Устройство бордюр                   В 15
# 5   поз.64  ...           Вертикал  1 этаж           В 25
#
#   actual_delivery_date fact_volume application_submission_date  \
# 1           2024-06-07           3                  2024-06-06
# 2           2024-06-09          96                  2024-06-06
# 3           2024-06-11         1,5                  2024-06-06
# 4           2024-06-07         2,5                  2024-06-07
# 5           2024-06-07         191                  2024-06-07
#
#   application_submission_time delivery_gap_days  delay_days  delay
# 1                          15                 1         0.0      0
# 2                          15                 1         2.0      1
# 3                          19                 1         4.0      1
# 4                           8                 0         0.0      0
# 5                           9                 0         0.0      0
#
# [5 rows x 21 columns]

# %%
round(df_since_june2024['delay'].value_counts(normalize=True) * 100)
# Out:
# delay
# 0    89.0
# 1    11.0
# Name: proportion, dtype: float64

# %%
df_final = df_since_june2024.drop(columns=['actual_delivery_date', 
                                           'mobility', 'phone', 'position', 'constructive', 'block',
                                           'floor', 'fact_volume', 'delay_days'], axis=1)
df_final.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  благоустройство    бетон
# 2            2024-06-07                     8           здание    бетон
# 3            2024-06-07                     9           здание    бетон
# 4            2024-06-07                     9  благоустройство    бетон
# 5            2024-06-07                     8           здание    бетон
#
#    volume  full_name                             object material_class  \
# 1     3.0  нуршабаев  благоустройство школа (нурлы жол)           В 15
# 2    90.0   адаменко                              спорт        В 25 СС
# 3     2.0     алинов                             другой           В 25
# 4     2.5  нуршабаев              благоустройство спорт           В 15
# 5   160.0     масхут                        нурлы жол 3           В 25
#
#   application_submission_date application_submission_time  delivery_gap_days  \
# 1                  2024-06-06                          15                  1
# 2                  2024-06-06                          15                  1
# 3                  2024-06-06                          19                  1
# 4                  2024-06-07                           8                  0
# 5                  2024-06-07                           9                  0
#
#    delay
# 1      0
# 2      1
# 3      1
# 4      0
# 5      0

# %%
print(df_final['material_class'].unique())
# Out:
# ['В 15' 'В 25 СС' 'В 25' 'В 7,5' 'М 100' 'В 12,5' 'В 20 СС'
#  'Пескобетон М200' 'В 30' 'В 20' 'М 50' 'Пескобетон М150'
#  'Пескобетон М100' 'Пескобетон М250' 'В 22,5' 'М 75' 'Пескобетон М400'
#  'Пескобетон М350' 'В 15 СС' 'Бетон М350' 'В 22,5 СС' 'B 40 F 300'
#  'В 7,5 СС' 'В 30 СС']

# %%
df_final['material_class'] = df_final['material_class'].replace('Бетон М350', 'В 22,5')
print(df_final['material_class'].unique())
# Out:
# ['В 15' 'В 25 СС' 'В 25' 'В 7,5' 'М 100' 'В 12,5' 'В 20 СС'
#  'Пескобетон М200' 'В 30' 'В 20' 'М 50' 'Пескобетон М150'
#  'Пескобетон М100' 'Пескобетон М250' 'В 22,5' 'М 75' 'Пескобетон М400'
#  'Пескобетон М350' 'В 15 СС' 'В 22,5 СС' 'B 40 F 300' 'В 7,5 СС' 'В 30 СС']

# %%
df_final['planned_delivery_weekday'] = df_final['planned_delivery_date'].dt.weekday + 1
df_final['planned_delivery_year'] = df_final['planned_delivery_date'].dt.year
df_final['planned_delivery_month'] = df_final['planned_delivery_date'].dt.month
df_final['planned_delivery_day'] = df_final['planned_delivery_date'].dt.day
df_final.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  благоустройство    бетон
# 2            2024-06-07                     8           здание    бетон
# 3            2024-06-07                     9           здание    бетон
# 4            2024-06-07                     9  благоустройство    бетон
# 5            2024-06-07                     8           здание    бетон
#
#    volume  full_name                             object material_class  \
# 1     3.0  нуршабаев  благоустройство школа (нурлы жол)           В 15
# 2    90.0   адаменко                              спорт        В 25 СС
# 3     2.0     алинов                             другой           В 25
# 4     2.5  нуршабаев              благоустройство спорт           В 15
# 5   160.0     масхут                        нурлы жол 3           В 25
#
#   application_submission_date application_submission_time  delivery_gap_days  \
# 1                  2024-06-06                          15                  1
# 2                  2024-06-06                          15                  1
# 3                  2024-06-06                          19                  1
# 4                  2024-06-07                           8                  0
# 5                  2024-06-07                           9                  0
#
#    delay  planned_delivery_weekday  planned_delivery_year  \
# 1      0                         5                   2024
# 2      1                         5                   2024
# 3      1                         5                   2024
# 4      0                         5                   2024
# 5      0                         5                   2024
#
#    planned_delivery_month  planned_delivery_day
# 1                       6                     7
# 2                       6                     7
# 3                       6                     7
# 4                       6                     7
# 5                       6                     7

# %%
df_final['application_submission_weekday'] = df_final['application_submission_date'].dt.weekday + 1
df_final['application_submission_year'] = df_final['application_submission_date'].dt.year
df_final['application_submission_month'] = df_final['application_submission_date'].dt.month
df_final.head()
# Out:
#   planned_delivery_date planned_delivery_time             type material  \
# 1            2024-06-07                     9  благоустройство    бетон
# 2            2024-06-07                     8           здание    бетон
# 3            2024-06-07                     9           здание    бетон
# 4            2024-06-07                     9  благоустройство    бетон
# 5            2024-06-07                     8           здание    бетон
#
#    volume  full_name                             object material_class  \
# 1     3.0  нуршабаев  благоустройство школа (нурлы жол)           В 15
# 2    90.0   адаменко                              спорт        В 25 СС
# 3     2.0     алинов                             другой           В 25
# 4     2.5  нуршабаев              благоустройство спорт           В 15
# 5   160.0     масхут                        нурлы жол 3           В 25
#
#   application_submission_date application_submission_time  delivery_gap_days  \
# 1                  2024-06-06                          15                  1
# 2                  2024-06-06                          15                  1
# 3                  2024-06-06                          19                  1
# 4                  2024-06-07                           8                  0
# 5                  2024-06-07                           9                  0
#
#    delay  planned_delivery_weekday  planned_delivery_year  \
# 1      0                         5                   2024
# 2      1                         5                   2024
# 3      1                         5                   2024
# 4      0                         5                   2024
# 5      0                         5                   2024
#
#    planned_delivery_month  planned_delivery_day  \
# 1                       6                     7
# 2                       6                     7
# 3                       6                     7
# 4                       6                     7
# 5                       6                     7
#
#    application_submission_weekday  application_submission_year  \
# 1                               4                         2024
# 2                               4                         2024
# 3                               4                         2024
# 4                               5                         2024
# 5                               5                         2024
#
#    application_submission_month
# 1                             6
# 2                             6
# 3                             6
# 4                             6
# 5                             6

# %%
df_ready = df_final.drop(columns=['planned_delivery_date', 'application_submission_date'], axis=1)
df_ready.head()
# Out:
#   planned_delivery_time             type material  volume  full_name  \
# 1                     9  благоустройство    бетон     3.0  нуршабаев
# 2                     8           здание    бетон    90.0   адаменко
# 3                     9           здание    бетон     2.0     алинов
# 4                     9  благоустройство    бетон     2.5  нуршабаев
# 5                     8           здание    бетон   160.0     масхут
#
#                               object material_class  \
# 1  благоустройство школа (нурлы жол)           В 15
# 2                              спорт        В 25 СС
# 3                             другой           В 25
# 4              благоустройство спорт           В 15
# 5                        нурлы жол 3           В 25
#
#   application_submission_time  delivery_gap_days  delay  \
# 1                          15                  1      0
# 2                          15                  1      1
# 3                          19                  1      1
# 4                           8                  0      0
# 5                           9                  0      0
#
#    planned_delivery_weekday  planned_delivery_year  planned_delivery_month  \
# 1                         5                   2024                       6
# 2                         5                   2024                       6
# 3                         5                   2024                       6
# 4                         5                   2024                       6
# 5                         5                   2024                       6
#
#    planned_delivery_day  application_submission_weekday  \
# 1                     7                               4
# 2                     7                               4
# 3                     7                               4
# 4                     7                               5
# 5                     7                               5
#
#    application_submission_year  application_submission_month
# 1                         2024                             6
# 2                         2024                             6
# 3                         2024                             6
# 4                         2024                             6
# 5                         2024                             6

# %%
df_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4084 entries, 1 to 4701
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   planned_delivery_time           4084 non-null   object
#  1   type                            4084 non-null   object
#  2   material                        4084 non-null   object
#  3   volume                          4084 non-null   float64
#  4   full_name                       4084 non-null   object
#  5   object                          4084 non-null   object
#  6   material_class                  4084 non-null   object
#  7   application_submission_time     4084 non-null   object
#  8   delivery_gap_days               4084 non-null   int64
#  9   delay                           4084 non-null   int64
#  10  planned_delivery_weekday        4084 non-null   int32
#  11  planned_delivery_year           4084 non-null   int32
#  12  planned_delivery_month          4084 non-null   int32
#  13  planned_delivery_day            4084 non-null   int32
#  14  application_submission_weekday  4084 non-null   int32
#  15  application_submission_year     4084 non-null   int32
#  16  application_submission_month    4084 non-null   int32
# dtypes: float64(1), int32(7), int64(2), object(7)
# memory usage: 462.6+ KB

# %%
df_ready[['planned_delivery_time', 'application_submission_time']] = df_ready[['planned_delivery_time', 
                                                                               'application_submission_time']].astype(int)
df_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4084 entries, 1 to 4701
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   planned_delivery_time           4084 non-null   int64
#  1   type                            4084 non-null   object
#  2   material                        4084 non-null   object
#  3   volume                          4084 non-null   float64
#  4   full_name                       4084 non-null   object
#  5   object                          4084 non-null   object
#  6   material_class                  4084 non-null   object
#  7   application_submission_time     4084 non-null   int64
#  8   delivery_gap_days               4084 non-null   int64
#  9   delay                           4084 non-null   int64
#  10  planned_delivery_weekday        4084 non-null   int32
#  11  planned_delivery_year           4084 non-null   int32
#  12  planned_delivery_month          4084 non-null   int32
#  13  planned_delivery_day            4084 non-null   int32
#  14  application_submission_weekday  4084 non-null   int32
#  15  application_submission_year     4084 non-null   int32
#  16  application_submission_month    4084 non-null   int32
# dtypes: float64(1), int32(7), int64(4), object(5)
# memory usage: 462.6+ KB

# %%
df_ready.head()
# Out:
#    planned_delivery_time             type material  volume  full_name  \
# 1                      9  благоустройство    бетон     3.0  нуршабаев
# 2                      8           здание    бетон    90.0   адаменко
# 3                      9           здание    бетон     2.0     алинов
# 4                      9  благоустройство    бетон     2.5  нуршабаев
# 5                      8           здание    бетон   160.0     масхут
#
#                               object material_class  \
# 1  благоустройство школа (нурлы жол)           В 15
# 2                              спорт        В 25 СС
# 3                             другой           В 25
# 4              благоустройство спорт           В 15
# 5                        нурлы жол 3           В 25
#
#    application_submission_time  delivery_gap_days  delay  \
# 1                           15                  1      0
# 2                           15                  1      1
# 3                           19                  1      1
# 4                            8                  0      0
# 5                            9                  0      0
#
#    planned_delivery_weekday  planned_delivery_year  planned_delivery_month  \
# 1                         5                   2024                       6
# 2                         5                   2024                       6
# 3                         5                   2024                       6
# 4                         5                   2024                       6
# 5                         5                   2024                       6
#
#    planned_delivery_day  application_submission_weekday  \
# 1                     7                               4
# 2                     7                               4
# 3                     7                               4
# 4                     7                               5
# 5                     7                               5
#
#    application_submission_year  application_submission_month
# 1                         2024                             6
# 2                         2024                             6
# 3                         2024                             6
# 4                         2024                             6
# 5                         2024                             6

# %%
delay_counts = df_ready.groupby(['planned_delivery_weekday', 'delay']).size().unstack(fill_value=0)

# %%
delay_percent = delay_counts.div(delay_counts.sum(axis=1), axis=0) * 100
delay_percent
# Out:
# delay                             0          1
# planned_delivery_weekday
# 1                         89.969605  10.030395
# 2                         88.381201  11.618799
# 3                         86.350148  13.649852
# 4                         93.273543   6.726457
# 5                         91.096979   8.903021
# 6                         89.183223  10.816777
# 7                         77.872340  22.127660

# %%
plt.bar(delay_percent.index, delay_percent[0], label='без задержки')
plt.bar(delay_percent.index, delay_percent[1], bottom=delay_percent[0], label='с задержкой')

for i, value in enumerate(delay_percent[0]):
    plt.text(delay_percent.index[i], y = value / 2, s=f'{value:.1f}%', ha='center', va='center', color='white')

for i, value in enumerate(delay_percent[1]):
    bottom=delay_percent[0].iloc[i]
    plt.text(delay_percent.index[i], y = bottom + value / 2, s=f'{value:.1f}%', ha='center', va='center', color='black')

plt.xlabel('День недели (1=Пн, 7=Вс)')
plt.ylabel('Процент заявок')
plt.title('Процент заявок с задержкой и без по дням недели')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## 📊 Вывод по графику: Процент заявок с задержкой поставки бетона по дням недели
#
# Анализ распределения задержек поставок бетона по дням недели показывает **чёткую цикличность** с пиками и провалами:
#
# * 📈 **Рост доли задержек** начинается с понедельника (9.7%) и достигает **максимума в среду** — **13.6%**.
# * ✅ **Наименьший процент задержек** наблюдается в **четверг** — всего **6.7%**, что может указывать на оптимальную организацию логистики в этот день.
# * 📉 После снижения в четверг доля задержек вновь начинает увеличиваться:
#
#   * Четверг — **6.7%**
#   * Пятница — **9.1%**
#   * Суббота — **10.8%**
#   * 📌 **Воскресенье показывает максимальную долю задержек** — **22.2%**, почти каждая **пятая заявка** поступает с отставанием от плана.
# * В то же время **наивысшая надёжность доставки** — в четверг (93.3% заявок доставлены вовремя).
#
# ### 🧩 Возможные причины:
#
# * Накопление заявок к середине недели может создавать нагрузку на поставки.
# * Четверг может быть днём когда к середине недели наиболее важные заявки были уже исполнены.
# * Высокая доля задержек в выходные (особенно в воскресенье) может быть связана с сокращением рабочих смен, транспорта.
#
# ---
#
# ### 📌 Рекомендации:
#
# * Использовать **четверг как день** для ключевых заливок и поставок.
# * Усилить **планирование поставок на выходные**.
# * Проанализировать **нагрузку по заявкам на среду и субботу**, где задержки превышают 10%.

# %%
delay_by_time = df_ready.groupby(['application_submission_time', 'delay']).size().unstack(fill_value=0)
delay_by_time_percent = delay_by_time.div(delay_by_time.sum(axis=1), axis=0) * 100

plt.figure(figsize=(12, 4))
plt.bar(delay_by_time_percent.index, delay_by_time_percent[0], label='без задержки')
plt.bar(delay_by_time_percent.index, delay_by_time_percent[1], bottom=delay_by_time_percent[0], label='с задержкой')

for i, value in enumerate(delay_by_time_percent[0]):
    plt.text(delay_by_time_percent.index[i], y = value / 2, s=f'{value:.0f}%', ha='center', va='center', color='white')

for i, value in enumerate(delay_by_time_percent[1]):
    bottom=delay_by_time_percent[0].iloc[i]
    plt.text(delay_by_time_percent.index[i], y = bottom + value / 2, s=f'{value:.0f}%', ha='center', va='center', color='black')


plt.xlabel('Время суток')
plt.ylabel('Процент заявок')
plt.ylim(0, 105)
plt.title('Влияние времени подачи заявки на вероятность задержки')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Интерпретация графика: Зависимость вероятности задержки от времени подачи заявки
#
# ### ⏰ 0–8 часов: Минимальный риск задержек (0–7%)
# - **Доля заявок с задержкой:** от **0% до 7%**
# - **Доля своевременных заявок:** от **93% до 100%**
#
# 💡 *Возможная причина:* эти заявки обрабатываются в первую очередь, поскольку поступают до начала рабочего дня диспетчера и попадают в его внимание в числе первых.
#
# ---
#
# ### ⚠️ 9–10 часов: Рост вероятности задержек (13–14%)
# - **Доля заявок с задержкой:** **13–14%**
# - **Доля своевременных заявок:** **86–87%**
#
# 💡 *Предположение:* заявки на это время подаются **в последний момент**, когда бетон нужен "на сегодня", а логистика уже загружена.
#
# ---
#
# ### 🍽 11–12 часов: Умеренное снижение задержек (12–8%)
# - **Доля заявок с задержкой:** **12% в 11:00**, **8% в 12:00**
# - **Доля своевременных заявок:** **88–92%**
#
# 💡 *Возможное объяснение:* заявки, поданные вблизи обеда, могут быть **обработаны в свободное время диспетчера**, снижая долю задержек.
#
# ---
#
# ### 🚨 13–14 часов: Пик задержек (15–20%)
# - **Доля заявок с задержкой:** **15% в 13:00**, **20% в 14:00**
# - **Доля своевременных заявок:** **85–80%**
#
# 💡 *Обоснование:* высокий процент срочных заявок, поданных ближе к середине дня, когда большая часть ресурсов уже распределена. Такие заявки **часто переносятся на следующий день**.
#
# ---
#
# ### 📉 После 15:00: Постепенное снижение задержек (16% → 6%)
# - **Доля заявок с задержкой:** от **16% в 15:00** до **6% в 23:00**
# - **Доля своевременных заявок:** растёт с **84% до 94%**
#
# 💡 *Интерпретация:* большинство заявок, поданных во второй половине дня, **предназначены на следующий день**, что даёт больше времени на планирование и снижает вероятность задержек.
#
# ---
#
# ### ✅ Вывод:
# Наибольшая вероятность задержки наблюдается в первой половине дня, особенно **с 9 до 14 часов**.
# Минимальная вероятность — **до 8:00** и **после 18:00**, когда заявки, как правило, **планируются на будущее**, а не на текущий день.

# %%
df_groupby_day = pd.DataFrame(df_ready.groupby(['planned_delivery_year', 
                                                'planned_delivery_month', 
                                                'planned_delivery_day', 
                                                'planned_delivery_weekday'])['volume'].sum().reset_index())
df_mean_weekday = df_groupby_day.groupby(['planned_delivery_weekday'])['volume'].mean()
df_mean_weekday.head(50)
# Out:
# planned_delivery_weekday
# 1    183.782444
# 2    226.696018
# 3    188.072750
# 4    194.071698
# 5    162.889623
# 6    179.441509
# 7    134.765306
# Name: volume, dtype: float64

# %%
df_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4084 entries, 1 to 4701
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   planned_delivery_time           4084 non-null   int64
#  1   type                            4084 non-null   object
#  2   material                        4084 non-null   object
#  3   volume                          4084 non-null   float64
#  4   full_name                       4084 non-null   object
#  5   object                          4084 non-null   object
#  6   material_class                  4084 non-null   object
#  7   application_submission_time     4084 non-null   int64
#  8   delivery_gap_days               4084 non-null   int64
#  9   delay                           4084 non-null   int64
#  10  planned_delivery_weekday        4084 non-null   int32
#  11  planned_delivery_year           4084 non-null   int32
#  12  planned_delivery_month          4084 non-null   int32
#  13  planned_delivery_day            4084 non-null   int32
#  14  application_submission_weekday  4084 non-null   int32
#  15  application_submission_year     4084 non-null   int32
#  16  application_submission_month    4084 non-null   int32
# dtypes: float64(1), int32(7), int64(4), object(5)
# memory usage: 462.6+ KB

# %%
X = df_ready.drop(columns='delay', axis=1)
y = df_ready['delay']

# %%
num_col = X.select_dtypes(include='number').columns
cat_col = df_ready.select_dtypes(exclude='number').columns
print(num_col)
print(cat_col)
# Out:
# Index(['planned_delivery_time', 'volume', 'application_submission_time',
#        'delivery_gap_days', 'planned_delivery_weekday',
#        'planned_delivery_year', 'planned_delivery_month',
#        'planned_delivery_day', 'application_submission_weekday',
#        'application_submission_year', 'application_submission_month'],
#       dtype='object')
# Index(['type', 'material', 'full_name', 'object', 'material_class'], dtype='object')

# %%
num_transform = Pipeline(steps=[
    ('scaler', StandardScaler())
])

# %%
cat_transform = Pipeline(steps=[
    ('onehot', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transform, num_col),
    ('cat', cat_transform, cat_col)
])

# %%
clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(class_weight='balanced'))
    # ('classifier', LogisticRegression())
])

# %%
random_state = 42
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=random_state)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3267, 16), (817, 16), (3267,), (817,))

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['planned_delivery_time', 'volume', 'application_submission_time',
#        'delivery_gap_days', 'planned_delivery_weekday',
#        'planned_delivery_year', 'planned_delivery_month',
#        'planned_delivery_day', 'application_submission_weekday',
#        'application_submission_year', 'application_submission_month'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   Index(['type', 'material', 'full_name', 'object', 'material_class'], dtype='object'))])),
#                 ('classifier', LogisticRegression(class_weight='balanced'))])

# %%
y_pred = clf.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [2, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
print('Accuracy - доля правильных предсказаний:', accuracy_score(y_test, y_pred))
print('Precision - сколько из предсказанных 1 действительно 1:', precision_score(y_test, y_pred))
print('Recall - сколько из настоящих 1 нашли:', recall_score(y_test, y_pred))
print('F1-score - гармония между precision и recall:', f1_score(y_test, y_pred))
print('ROC auc - общая способность модели отделять классы:', roc_auc_score(y_test, y_pred))
# Out:
# Accuracy - доля правильных предсказаний: 0.7931456548347613
# Precision - сколько из предсказанных 1 действительно 1: 0.28703703703703703
# Recall - сколько из настоящих 1 нашли: 0.8051948051948052
# F1-score - гармония между precision и recall: 0.4232081911262799
# ROC auc - общая способность модели отделять классы: 0.7985433485433486

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['без задержки', 'с задержкой'])
fig, ax = plt.subplots(figsize=(5, 4))
disp.plot(cmap='Blues', ax=ax)
ax.set_ylabel('Фактический класс')
ax.set_xlabel('Предсказанный класс')
ax.set_yticklabels(['без задержки', 'с задержкой'], rotation=90, va='center')
plt.show()
