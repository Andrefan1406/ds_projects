# %% [markdown]
# # О проекте

# %% [markdown]
# ## Проект: Автоматический подсчёт арматуры на фото с использованием компьютерного зрения
#
# ![🏗️](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRqtyt0A1JvTb3C9JtG8znuHshzOHdQWI9FdA&s)
#
# В строительной компании, специализирующейся на возведении зданий с монолитным каркасом, ежедневно используется большое количество арматуры:
#
# **🔩 Арматура** — ключевой материал при возведении железобетонных конструкций.
#
# Для упрощения контроля остатков арматуры на складах строительных участков разрабатывается **модель машинного обучения**, способная по фотографии **автоматически подсчитывать количество арматурных стержней в пачке**:
#
# ![пример фото торца арматуры](https://ros-met.com/wp-content/uploads/2020/06/at800.jpg)
#
# ---
#
# ### 🎯 Цель проекта
#
# Создание системы, позволяющей:
#
# * 📦 Вести **автоматический учёт арматуры** по фото
# * 👷 Облегчить работу кладовщиков и инженеров
# * 📉 Уменьшить ошибки при **списании и заявках**
# * 🔍 Усилить контроль за остатками арматуры на складах
#
# ---
#
# ### 🧠 Технический подход
#
# * 📸 Сбор и разметка изображений торцов пачек арматуры
# * 🧠 Обучение модели **компьютерного зрения** на этих данных
# * 🧪 Валидация и внедрение в производственный процесс
#
# ---
#
# ### 💡 Применение
#
# Модель будет использоваться на стройплощадках в составе мобильного или веб-приложения для:
#
# * Склада и логистики
# * Учетных отделов
# * Технического надзора
